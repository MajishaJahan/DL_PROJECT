# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
train_dir = '/kaggle/input/pcos-detection-using-ultrasound-images/data/train'
test_dir = '/kaggle/input/pcos-detection-using-ultrasound-images/data/test'
image_size = (224, 224)  


def load_images_from_folder(base_dir):
    images = []
    labels = []
    classes = {'infected': 1, 'notinfected': 0} 
    for label in classes:
        folder_path = os.path.join(base_dir, label)
        for image_file in os.listdir(folder_path):
            img_path = os.path.join(folder_path, image_file)
            img = cv2.imread(img_path)
            if img is not None:
                img = cv2.resize(img, image_size)
                images.append(img)
                labels.append(classes[label])
    return np.array(images), np.array(labels)


train_images, train_labels = load_images_from_folder(train_dir)
test_images, test_labels = load_images_from_folder(test_dir)

train_images = train_images / 255.0
test_images = test_images / 255.0

print(test_images[0])
# Out:
# [[[0.01568627 0.         0.        ]
#   [0.03137255 0.01568627 0.01176471]
#   [0.08235294 0.06666667 0.0627451 ]
#   ...
#   [0.         0.00392157 0.        ]
#   [0.         0.01568627 0.01176471]
#   [0.00784314 0.01176471 0.00392157]]
#
#  [[0.04705882 0.03137255 0.02745098]
#   [0.09803922 0.08235294 0.07843137]
#   [0.21568627 0.2        0.19607843]
#   ...
#   [0.         0.00392157 0.        ]
#   [0.         0.         0.        ]
#   [0.00392157 0.00784314 0.        ]]
#
#  [[0.33333333 0.31764706 0.31372549]
#   [0.25490196 0.23921569 0.23529412]
#   [0.21568627 0.2        0.19607843]
#   ...
#   [0.02352941 0.03137255 0.03137255]
#   [0.02745098 0.03529412 0.03529412]
#   [0.00392157 0.00784314 0.        ]]
#
#  ...
#
#  [[0.61176471 0.61176471 0.61176471]
#   [0.61176471 0.61176471 0.61176471]
#   [0.61176471 0.61176471 0.61176471]
#   ...
#   [0.61176471 0.61176471 0.61176471]
#   [0.61176471 0.61176471 0.61176471]
#   [0.61176471 0.61176471 0.61176471]]
#
#  [[0.61176471 0.61176471 0.61176471]
#   [0.61176471 0.61176471 0.61176471]
#   [0.61176471 0.61176471 0.61176471]
#   ...
#   [0.61176471 0.61176471 0.61176471]
#   [0.61176471 0.61176471 0.61176471]
#   [0.61176471 0.61176471 0.61176471]]
#
#  [[0.61176471 0.61176471 0.61176471]
#   [0.61176471 0.61176471 0.61176471]
#   [0.61176471 0.61176471 0.61176471]
#   ...
#   [0.61176471 0.61176471 0.61176471]
#   [0.61176471 0.61176471 0.61176471]
#   [0.61176471 0.61176471 0.61176471]]]

# %%
from tensorflow.keras.utils import to_categorical
X_train, X_val, y_train, y_val = train_test_split(train_images, train_labels, test_size=0.15, random_state=42)

y_train = to_categorical(y_train, 2)
y_val = to_categorical(y_val, 2)
y_test = to_categorical(test_labels, 2)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)


datagen.fit(X_train)

# %% [markdown]
# # **RESNET50**

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D


# base_model = ResNet50(weights="imagenet", include_top=False, input_shape=(224, 224, 3))

base_model = ResNet50(weights='/kaggle/input/resnet50/keras/default/1/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5',
                      include_top=False, 
                      input_shape=(224, 224, 3))



x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(2, activation='softmax')(x)


model = Model(inputs=base_model.input, outputs=predictions)

for layer in base_model.layers:
    layer.trainable = False

# %%
from tensorflow.keras.optimizers import Adam

model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='binary_crossentropy',
              metrics=['accuracy'])


history = model.fit(
    datagen.flow(X_train, y_train, batch_size=32),
    validation_data=(X_val, y_val),
    epochs=55,
    verbose=1
)
# Out:
# Epoch 1/55
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1736493206.180221      68 service.cc:145] XLA service 0x78f3280032b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1736493206.180269      68 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1736493206.180275      68 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
#  1/52 ━━━━━━━━━━━━━━━━━━━━ 14:34 17s/step - accuracy: 0.6562 - loss: 0.6956
# I0000 00:00:1736493214.679330      68 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 42s 485ms/step - accuracy: 0.5834 - loss: 0.7821 - val_accuracy: 0.6021 - val_loss: 0.6480
# Epoch 2/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 285ms/step - accuracy: 0.5953 - loss: 0.6977 - val_accuracy: 0.6021 - val_loss: 0.6434
# Epoch 3/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 271ms/step - accuracy: 0.5897 - loss: 0.6834 - val_accuracy: 0.6021 - val_loss: 0.6240
# Epoch 4/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 278ms/step - accuracy: 0.6348 - loss: 0.6522 - val_accuracy: 0.6920 - val_loss: 0.5887
# Epoch 5/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 273ms/step - accuracy: 0.6738 - loss: 0.6250 - val_accuracy: 0.8478 - val_loss: 0.5287
# Epoch 6/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 276ms/step - accuracy: 0.7283 - loss: 0.5785 - val_accuracy: 0.9377 - val_loss: 0.4579
# Epoch 7/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 281ms/step - accuracy: 0.8012 - loss: 0.5177 - val_accuracy: 0.9135 - val_loss: 0.3829
# Epoch 8/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 279ms/step - accuracy: 0.8155 - loss: 0.4773 - val_accuracy: 0.9654 - val_loss: 0.3243
# Epoch 9/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 277ms/step - accuracy: 0.8773 - loss: 0.4195 - val_accuracy: 0.9619 - val_loss: 0.3009
# Epoch 10/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 282ms/step - accuracy: 0.9038 - loss: 0.3601 - val_accuracy: 0.9689 - val_loss: 0.2599
# Epoch 11/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 275ms/step - accuracy: 0.8975 - loss: 0.3289 - val_accuracy: 0.9827 - val_loss: 0.1982
# Epoch 12/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 283ms/step - accuracy: 0.9209 - loss: 0.2841 - val_accuracy: 0.9827 - val_loss: 0.1689
# Epoch 13/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 283ms/step - accuracy: 0.9188 - loss: 0.2667 - val_accuracy: 0.9758 - val_loss: 0.1476
# Epoch 14/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 278ms/step - accuracy: 0.9228 - loss: 0.2456 - val_accuracy: 0.9827 - val_loss: 0.1151
# Epoch 15/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 279ms/step - accuracy: 0.9159 - loss: 0.2348 - val_accuracy: 0.9862 - val_loss: 0.1038
# Epoch 16/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 274ms/step - accuracy: 0.9372 - loss: 0.1983 - val_accuracy: 0.9896 - val_loss: 0.1019
# Epoch 17/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 280ms/step - accuracy: 0.9470 - loss: 0.1856 - val_accuracy: 0.9758 - val_loss: 0.1188
# Epoch 18/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 277ms/step - accuracy: 0.9379 - loss: 0.1846 - val_accuracy: 0.9758 - val_loss: 0.1042
# Epoch 19/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 277ms/step - accuracy: 0.9478 - loss: 0.1730 - val_accuracy: 0.9931 - val_loss: 0.0828
# Epoch 20/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 276ms/step - accuracy: 0.9475 - loss: 0.1564 - val_accuracy: 0.9550 - val_loss: 0.1572
# Epoch 21/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 281ms/step - accuracy: 0.9566 - loss: 0.1596 - val_accuracy: 0.9896 - val_loss: 0.0747
# Epoch 22/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 277ms/step - accuracy: 0.9455 - loss: 0.1523 - val_accuracy: 0.9758 - val_loss: 0.0972
# Epoch 23/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 276ms/step - accuracy: 0.9507 - loss: 0.1509 - val_accuracy: 0.9931 - val_loss: 0.0668
# Epoch 24/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 275ms/step - accuracy: 0.9469 - loss: 0.1463 - val_accuracy: 0.9758 - val_loss: 0.0745
# Epoch 25/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 289ms/step - accuracy: 0.9480 - loss: 0.1501 - val_accuracy: 0.9723 - val_loss: 0.0959
# Epoch 26/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 279ms/step - accuracy: 0.9555 - loss: 0.1337 - val_accuracy: 0.9896 - val_loss: 0.0624
# Epoch 27/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 281ms/step - accuracy: 0.9645 - loss: 0.1198 - val_accuracy: 0.9931 - val_loss: 0.0509
# Epoch 28/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 278ms/step - accuracy: 0.9424 - loss: 0.1492 - val_accuracy: 0.9931 - val_loss: 0.0610
# Epoch 29/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 283ms/step - accuracy: 0.9474 - loss: 0.1385 - val_accuracy: 1.0000 - val_loss: 0.0348
# Epoch 30/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 284ms/step - accuracy: 0.9526 - loss: 0.1333 - val_accuracy: 1.0000 - val_loss: 0.0313
# Epoch 31/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 279ms/step - accuracy: 0.9671 - loss: 0.0979 - val_accuracy: 0.9723 - val_loss: 0.0833
# Epoch 32/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 275ms/step - accuracy: 0.9638 - loss: 0.1148 - val_accuracy: 1.0000 - val_loss: 0.0321
# Epoch 33/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 280ms/step - accuracy: 0.9626 - loss: 0.1107 - val_accuracy: 1.0000 - val_loss: 0.0261
# Epoch 34/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 281ms/step - accuracy: 0.9706 - loss: 0.0918 - val_accuracy: 0.9965 - val_loss: 0.0379
# Epoch 35/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 281ms/step - accuracy: 0.9667 - loss: 0.0952 - val_accuracy: 1.0000 - val_loss: 0.0256
# Epoch 36/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 281ms/step - accuracy: 0.9552 - loss: 0.1323 - val_accuracy: 0.9965 - val_loss: 0.0419
# Epoch 37/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 284ms/step - accuracy: 0.9649 - loss: 0.1019 - val_accuracy: 1.0000 - val_loss: 0.0231
# Epoch 38/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 283ms/step - accuracy: 0.9637 - loss: 0.1100 - val_accuracy: 0.9965 - val_loss: 0.0339
# Epoch 39/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 276ms/step - accuracy: 0.9713 - loss: 0.0915 - val_accuracy: 1.0000 - val_loss: 0.0176
# Epoch 40/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 280ms/step - accuracy: 0.9657 - loss: 0.1039 - val_accuracy: 1.0000 - val_loss: 0.0165
# Epoch 41/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 284ms/step - accuracy: 0.9695 - loss: 0.0914 - val_accuracy: 1.0000 - val_loss: 0.0146
# Epoch 42/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 281ms/step - accuracy: 0.9685 - loss: 0.1004 - val_accuracy: 1.0000 - val_loss: 0.0196
# Epoch 43/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 282ms/step - accuracy: 0.9728 - loss: 0.0851 - val_accuracy: 1.0000 - val_loss: 0.0126
# Epoch 44/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 282ms/step - accuracy: 0.9705 - loss: 0.1079 - val_accuracy: 1.0000 - val_loss: 0.0266
# Epoch 45/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 278ms/step - accuracy: 0.9791 - loss: 0.0691 - val_accuracy: 1.0000 - val_loss: 0.0219
# Epoch 46/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 283ms/step - accuracy: 0.9668 - loss: 0.0850 - val_accuracy: 1.0000 - val_loss: 0.0294
# Epoch 47/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 280ms/step - accuracy: 0.9646 - loss: 0.1069 - val_accuracy: 1.0000 - val_loss: 0.0175
# Epoch 48/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 280ms/step - accuracy: 0.9721 - loss: 0.0772 - val_accuracy: 1.0000 - val_loss: 0.0253
# Epoch 49/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 278ms/step - accuracy: 0.9596 - loss: 0.1017 - val_accuracy: 1.0000 - val_loss: 0.0141
# Epoch 50/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 277ms/step - accuracy: 0.9748 - loss: 0.0823 - val_accuracy: 1.0000 - val_loss: 0.0208
# Epoch 51/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 276ms/step - accuracy: 0.9750 - loss: 0.0802 - val_accuracy: 1.0000 - val_loss: 0.0096
# Epoch 52/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 280ms/step - accuracy: 0.9601 - loss: 0.1033 - val_accuracy: 1.0000 - val_loss: 0.0082
# Epoch 53/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 281ms/step - accuracy: 0.9701 - loss: 0.0797 - val_accuracy: 1.0000 - val_loss: 0.0114
# Epoch 54/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 275ms/step - accuracy: 0.9761 - loss: 0.0825 - val_accuracy: 1.0000 - val_loss: 0.0297
# Epoch 55/55
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 281ms/step - accuracy: 0.9768 - loss: 0.0737 - val_accuracy: 1.0000 - val_loss: 0.0088

# %%
# Evaluate on the test set
test_loss, test_acc = model.evaluate(test_images, y_test)
print(f"Test Accuracy: {test_acc}")
# Out:
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 8s 129ms/step - accuracy: 0.9869 - loss: 0.0252
# Test Accuracy: 0.9916753172874451

# %%
# # model.save('full_model_1.h5')
# from tensorflow.keras.models import load_model

# # Load the saved model
# model = load_model('/kaggle/working/full_model_1.h5')

# # Example testing code
# # results = model.evaluate(X_test, y_test, verbose=1)
# test_loss, test_acc = model.evaluate(test_images, y_test)
# print(f"Test Loss: {test_loss}")
# print(f"Test Accuracy: {test_acc}")

# # Making predictions
# predictions = model.predict(test_images)

# %% [markdown]
# # CNN with pre-trained VGGNet16

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D
import numpy as np
import xgboost as xgb
from sklearn.metrics import accuracy_score
X_test=test_images

vgg_model = VGG16(weights='/kaggle/input/vggnet16/keras/default/1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5',
                  include_top=False, input_shape=(224, 224, 3))

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score, confusion_matrix, classification_report


# Add a global spatial average pooling layer
x = vgg_model.output
x = GlobalAveragePooling2D()(x)


feature_extractor = Model(inputs=vgg_model.input, outputs=x)

for layer in vgg_model.layers:
    layer.trainable = False


X_train_features = feature_extractor.predict(X_train)
X_val_features = feature_extractor.predict(X_val)
X_test_features = feature_extractor.predict(X_test)


X_train_features = X_train_features.reshape((X_train_features.shape[0], -1))
X_val_features = X_val_features.reshape((X_val_features.shape[0], -1))
X_test_features = X_test_features.reshape((X_test_features.shape[0], -1))

xgb_model = xgb.XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=4)


xgb_model.fit(X_train_features, y_train)

val_predictions = xgb_model.predict(X_val_features)
val_proba = xgb_model.predict_proba(X_val_features)
val_roc_auc = roc_auc_score(y_val, val_proba, multi_class='ovr', average='macro')

# val_proba = model.predict_proba(X_val)


test_predictions = xgb_model.predict(X_test_features)

test_proba = xgb_model.predict_proba(X_test_features)
test_roc_auc = roc_auc_score(y_test, test_proba, multi_class='ovr', average='macro')



val_accuracy = accuracy_score(y_val, val_predictions)
val_f1 = f1_score(y_val, val_predictions, average='macro')  
val_precision = precision_score(y_val, val_predictions, average='macro')
val_recall = recall_score(y_val, val_predictions, average='macro')
# val_roc_auc = roc_auc_score(y_val, val_proba)

test_accuracy = accuracy_score(y_test, test_predictions)
test_f1 = f1_score(y_test, test_predictions, average='macro')
test_precision = precision_score(y_test, test_predictions, average='macro')
test_recall = recall_score(y_test, test_predictions, average='macro')

print(f'Validation Accuracy: {val_accuracy * 100:.5f}%')
print(f'Validation F1 Score: {val_f1:.5f}')
print(f'Validation Precision: {val_precision:.5f}')
print(f'Validation Recall: {val_recall:.5f}')
print(f'Validation ROC AUC: {val_roc_auc:.5f}')
# print('Validation Confusion Matrix:')
# print(val_confusion_matrix)
# print('Validation Classification Report:')
# print(val_classification_report)


print(f'Test Accuracy: {test_accuracy * 100:.5f}%')
print(f'Test F1 Score: {test_f1:.5f}')
print(f'Test Precision: {test_precision:.5f}')
print(f'Test Recall: {test_recall:.5f}')
print(f'Test ROC AUC: {test_roc_auc:.5f}')
y_val_class = np.argmax(y_val, axis=1)
val_predictions_class = np.argmax(val_predictions, axis=1)

y_test_class = np.argmax(y_test, axis=1)
test_predictions_class = np.argmax(test_predictions, axis=1)

# Now use these in confusion_matrix and classification_report
val_confusion_matrix = confusion_matrix(y_val_class, val_predictions_class)
val_classification_report = classification_report(y_val_class, val_predictions_class)

test_confusion_matrix = confusion_matrix(y_test_class, test_predictions_class)
test_classification_report = classification_report(y_test_class, test_predictions_class)
print('Test Confusion Matrix:')
print(test_confusion_matrix)
print('Test Classification Report:')
print(test_classification_report)
# Out:
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 29s 222ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 334ms/step
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 12s 196ms/step
# Validation Accuracy: 99.65398%
# Validation F1 Score: 0.99639
# Validation Precision: 0.99569
# Validation Recall: 0.99713
# Validation ROC AUC: 1.00000
# Test Accuracy: 99.94797%
# Test F1 Score: 0.99946
# Test Precision: 0.99936
# Test Recall: 0.99956
# Test ROC AUC: 1.00000
# Test Confusion Matrix:
# [[1140    1]
#  [   0  781]]
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1141
#            1       1.00      1.00      1.00       781
#
#     accuracy                           1.00      1922
#    macro avg       1.00      1.00      1.00      1922
# weighted avg       1.00      1.00      1.00      1922

# %%
# import pickle
# import numpy as np
# from sklearn.metrics import accuracy_score
# from tensorflow.keras.models import load_model

# filename = 'full-model_2.h5'
# # model.save(filename)


# # Load the saved model
# loaded_model = load_model(filename)

# print("Model loaded successfully")

# # Predict using the loaded model
# loaded_model_predictions = loaded_model.predict(X_test)

# # Convert probabilities to class labels if needed (assuming multi-class classification)
# loaded_model_predictions = np.argmax(loaded_model_predictions, axis=1)

# # If y_test is one-hot encoded, convert it to class labels
# y_test_labels = np.argmax(y_test, axis=1)

# # Calculate accuracy
# test_accuracy = accuracy_score(y_test_labels, loaded_model_predictions)

# print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# %% [markdown]
# # Stacking Ensable with XGBooster

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
import xgboost as xgb
from sklearn.preprocessing import StandardScaler
import numpy as np

# Assuming y_train_single, y_val_single, and y_test_single are already 1D arrays of class labels
y_train_single = np.argmax(y_train, axis=1)
y_val_single = np.argmax(y_val, axis=1)
y_test_single= np.argmax(y_test, axis=1)
scaler = StandardScaler()
X_train_features = scaler.fit_transform(X_train_features)
X_val_features = scaler.transform(X_val_features)
X_test_features = scaler.transform(X_test_features)

# Initialize the base models
lr = LogisticRegression(max_iter=500)
rf = RandomForestClassifier(n_estimators=100)
svm = SVC(probability=True)

# Fit the base models
lr.fit(X_train_features, y_train_single)
rf.fit(X_train_features, y_train_single)
svm.fit(X_train_features, y_train_single)

# Get the predicted probabilities for stacking
lr_train_pred = lr.predict_proba(X_train_features)
rf_train_pred = rf.predict_proba(X_train_features)
svm_train_pred = svm.predict_proba(X_train_features)

# Concatenate the predictions to form the meta input
meta_X_train = np.hstack((lr_train_pred, rf_train_pred, svm_train_pred))

# Get validation predictions
lr_val_pred = lr.predict_proba(X_val_features)
rf_val_pred = rf.predict_proba(X_val_features)
svm_val_pred = svm.predict_proba(X_val_features)
meta_X_val = np.hstack((lr_val_pred, rf_val_pred, svm_val_pred))

# Initialize and train the meta-learner (XGBoost)
meta_learner = xgb.XGBClassifier(n_estimators=400, learning_rate=0.001, max_depth=4, eval_metric=['logloss', 'error'], use_label_encoder=False)

eval_set = [(meta_X_train, y_train_single), (meta_X_val, y_val_single)]
meta_learner.fit(meta_X_train, y_train_single, eval_set=eval_set, verbose=True)

# Get test predictions from the base models
lr_test_pred = lr.predict_proba(X_test_features)
rf_test_pred = rf.predict_proba(X_test_features)
svm_test_pred = svm.predict_proba(X_test_features)

# Concatenate the test set predictions for the meta learner
meta_X_test = np.hstack((lr_test_pred, rf_test_pred, svm_test_pred))


 # Convert one-hot encoded y_test_single to class labels if it's one-hot encoded
if len(y_test_single.shape) > 1 and y_test_single.shape[1] > 1:
    y_test_single_labels = np.argmax(y_test_single, axis=1)
else:
    y_test_single_labels = y_test_single  # Already in label format

# Predict the final class labels with the meta learner
y_pred = meta_learner.predict(meta_X_test)

# Now compute the metrics using the true labels and predictions
accuracy = accuracy_score(y_test_single_labels, y_pred)
f1 = f1_score(y_test_single_labels, y_pred, average='macro')
precision = precision_score(y_test_single_labels, y_pred, average='macro')
recall = recall_score(y_test_single_labels, y_pred, average='macro')
roc_auc = roc_auc_score(y_test_single_labels, y_pred, multi_class='ovr')

print(f'Accuracy: {accuracy}')
print(f'F1 Score: {f1}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'ROC AUC: {roc_auc}')
# Out:
# [0]	validation_0-logloss:0.67488	validation_0-error:0.40734	validation_1-logloss:0.67144	validation_1-error:0.39792
# [1]	validation_0-logloss:0.67389	validation_0-error:0.40734	validation_1-logloss:0.67049	validation_1-error:0.39792
# [2]	validation_0-logloss:0.67290	validation_0-error:0.40734	validation_1-logloss:0.66954	validation_1-error:0.39792
# [3]	validation_0-logloss:0.67192	validation_0-error:0.40734	validation_1-logloss:0.66859	validation_1-error:0.39792
# [4]	validation_0-logloss:0.67093	validation_0-error:0.40734	validation_1-logloss:0.66765	validation_1-error:0.39792
# [5]	validation_0-logloss:0.66995	validation_0-error:0.40734	validation_1-logloss:0.66671	validation_1-error:0.39792
# [6]	validation_0-logloss:0.66897	validation_0-error:0.40734	validation_1-logloss:0.66577	validation_1-error:0.39792
# [7]	validation_0-logloss:0.66799	validation_0-error:0.40734	validation_1-logloss:0.66483	validation_1-error:0.39792
# [8]	validation_0-logloss:0.66701	validation_0-error:0.40734	validation_1-logloss:0.66390	validation_1-error:0.39792
# [9]	validation_0-logloss:0.66604	validation_0-error:0.40734	validation_1-logloss:0.66297	validation_1-error:0.39792
# [10]	validation_0-logloss:0.66507	validation_0-error:0.40734	validation_1-logloss:0.66204	validation_1-error:0.39792
# [11]	validation_0-logloss:0.66410	validation_0-error:0.40734	validation_1-logloss:0.66111	validation_1-error:0.39792
# [12]	validation_0-logloss:0.66313	validation_0-error:0.40734	validation_1-logloss:0.66018	validation_1-error:0.39792
# [13]	validation_0-logloss:0.66216	validation_0-error:0.40734	validation_1-logloss:0.65925	validation_1-error:0.39792
# [14]	validation_0-logloss:0.66120	validation_0-error:0.40734	validation_1-logloss:0.65833	validation_1-error:0.39792
# [15]	validation_0-logloss:0.66023	validation_0-error:0.40734	validation_1-logloss:0.65741	validation_1-error:0.39792
# [16]	validation_0-logloss:0.65927	validation_0-error:0.40734	validation_1-logloss:0.65649	validation_1-error:0.39792
# [17]	validation_0-logloss:0.65831	validation_0-error:0.40734	validation_1-logloss:0.65557	validation_1-error:0.39792
# [18]	validation_0-logloss:0.65736	validation_0-error:0.40734	validation_1-logloss:0.65466	validation_1-error:0.39792
# [19]	validation_0-logloss:0.65640	validation_0-error:0.40734	validation_1-logloss:0.65375	validation_1-error:0.39792
# [20]	validation_0-logloss:0.65545	validation_0-error:0.40734	validation_1-logloss:0.65283	validation_1-error:0.39792
# [21]	validation_0-logloss:0.65450	validation_0-error:0.40734	validation_1-logloss:0.65192	validation_1-error:0.39792
# [22]	validation_0-logloss:0.65355	validation_0-error:0.40734	validation_1-logloss:0.65102	validation_1-error:0.39792
# [23]	validation_0-logloss:0.65261	validation_0-error:0.40734	validation_1-logloss:0.65011	validation_1-error:0.39792
# [24]	validation_0-logloss:0.65166	validation_0-error:0.40734	validation_1-logloss:0.64921	validation_1-error:0.39792
# [25]	validation_0-logloss:0.65072	validation_0-error:0.40734	validation_1-logloss:0.64831	validation_1-error:0.39792
# [26]	validation_0-logloss:0.64978	validation_0-error:0.40734	validation_1-logloss:0.64741	validation_1-error:0.39792
# [27]	validation_0-logloss:0.64884	validation_0-error:0.40734	validation_1-logloss:0.64651	validation_1-error:0.39792
# [28]	validation_0-logloss:0.64790	validation_0-error:0.40734	validation_1-logloss:0.64561	validation_1-error:0.39792
# [29]	validation_0-logloss:0.64697	validation_0-error:0.40734	validation_1-logloss:0.64472	validation_1-error:0.39792
# [30]	validation_0-logloss:0.64603	validation_0-error:0.40734	validation_1-logloss:0.64383	validation_1-error:0.39792
# [31]	validation_0-logloss:0.64510	validation_0-error:0.40734	validation_1-logloss:0.64293	validation_1-error:0.39792
# [32]	validation_0-logloss:0.64417	validation_0-error:0.40734	validation_1-logloss:0.64205	validation_1-error:0.39792
# [33]	validation_0-logloss:0.64325	validation_0-error:0.40734	validation_1-logloss:0.64116	validation_1-error:0.39792
# [34]	validation_0-logloss:0.64232	validation_0-error:0.40734	validation_1-logloss:0.64027	validation_1-error:0.39792
# [35]	validation_0-logloss:0.64140	validation_0-error:0.40734	validation_1-logloss:0.63939	validation_1-error:0.39792
# [36]	validation_0-logloss:0.64048	validation_0-error:0.40734	validation_1-logloss:0.63851	validation_1-error:0.39792
# [37]	validation_0-logloss:0.63956	validation_0-error:0.40734	validation_1-logloss:0.63763	validation_1-error:0.39792
# [38]	validation_0-logloss:0.63864	validation_0-error:0.40734	validation_1-logloss:0.63675	validation_1-error:0.39792
# [39]	validation_0-logloss:0.63772	validation_0-error:0.40734	validation_1-logloss:0.63588	validation_1-error:0.39792
# [40]	validation_0-logloss:0.63681	validation_0-error:0.40734	validation_1-logloss:0.63500	validation_1-error:0.39792
# [41]	validation_0-logloss:0.63590	validation_0-error:0.40734	validation_1-logloss:0.63413	validation_1-error:0.39792
# [42]	validation_0-logloss:0.63499	validation_0-error:0.40734	validation_1-logloss:0.63326	validation_1-error:0.39792
# [43]	validation_0-logloss:0.63408	validation_0-error:0.40734	validation_1-logloss:0.63239	validation_1-error:0.39792
# [44]	validation_0-logloss:0.63317	validation_0-error:0.40734	validation_1-logloss:0.63153	validation_1-error:0.39792
# [45]	validation_0-logloss:0.63226	validation_0-error:0.40734	validation_1-logloss:0.63066	validation_1-error:0.39792
# [46]	validation_0-logloss:0.63136	validation_0-error:0.40734	validation_1-logloss:0.62980	validation_1-error:0.39792
# [47]	validation_0-logloss:0.63046	validation_0-error:0.40734	validation_1-logloss:0.62894	validation_1-error:0.39792
# [48]	validation_0-logloss:0.62956	validation_0-error:0.40734	validation_1-logloss:0.62808	validation_1-error:0.39792
# [49]	validation_0-logloss:0.62866	validation_0-error:0.40734	validation_1-logloss:0.62722	validation_1-error:0.39792
# [50]	validation_0-logloss:0.62777	validation_0-error:0.40734	validation_1-logloss:0.62636	validation_1-error:0.39792
# [51]	validation_0-logloss:0.62687	validation_0-error:0.40734	validation_1-logloss:0.62551	validation_1-error:0.39792
# [52]	validation_0-logloss:0.62598	validation_0-error:0.40734	validation_1-logloss:0.62466	validation_1-error:0.39792
# [53]	validation_0-logloss:0.62509	validation_0-error:0.40734	validation_1-logloss:0.62381	validation_1-error:0.39792
# [54]	validation_0-logloss:0.62420	validation_0-error:0.40734	validation_1-logloss:0.62296	validation_1-error:0.39792
# [55]	validation_0-logloss:0.62331	validation_0-error:0.40734	validation_1-logloss:0.62211	validation_1-error:0.39792
# [56]	validation_0-logloss:0.62243	validation_0-error:0.40734	validation_1-logloss:0.62126	validation_1-error:0.39792
# [57]	validation_0-logloss:0.62155	validation_0-error:0.40734	validation_1-logloss:0.62042	validation_1-error:0.39792
# [58]	validation_0-logloss:0.62066	validation_0-error:0.40734	validation_1-logloss:0.61958	validation_1-error:0.39792
# [59]	validation_0-logloss:0.61978	validation_0-error:0.40734	validation_1-logloss:0.61874	validation_1-error:0.39792
# [60]	validation_0-logloss:0.61891	validation_0-error:0.40734	validation_1-logloss:0.61790	validation_1-error:0.39792
# [61]	validation_0-logloss:0.61803	validation_0-error:0.40734	validation_1-logloss:0.61706	validation_1-error:0.39792
# [62]	validation_0-logloss:0.61715	validation_0-error:0.40734	validation_1-logloss:0.61623	validation_1-error:0.39792
# [63]	validation_0-logloss:0.61628	validation_0-error:0.40734	validation_1-logloss:0.61539	validation_1-error:0.39792
# [64]	validation_0-logloss:0.61541	validation_0-error:0.40734	validation_1-logloss:0.61456	validation_1-error:0.39792
# [65]	validation_0-logloss:0.61454	validation_0-error:0.40734	validation_1-logloss:0.61373	validation_1-error:0.39792
# [66]	validation_0-logloss:0.61367	validation_0-error:0.40734	validation_1-logloss:0.61290	validation_1-error:0.39792
# [67]	validation_0-logloss:0.61281	validation_0-error:0.40734	validation_1-logloss:0.61207	validation_1-error:0.39792
# [68]	validation_0-logloss:0.61194	validation_0-error:0.40734	validation_1-logloss:0.61125	validation_1-error:0.39792
# [69]	validation_0-logloss:0.61108	validation_0-error:0.40734	validation_1-logloss:0.61042	validation_1-error:0.39792
# [70]	validation_0-logloss:0.61022	validation_0-error:0.40734	validation_1-logloss:0.60960	validation_1-error:0.39792
# [71]	validation_0-logloss:0.60936	validation_0-error:0.40734	validation_1-logloss:0.60878	validation_1-error:0.39792
# [72]	validation_0-logloss:0.60850	validation_0-error:0.40734	validation_1-logloss:0.60796	validation_1-error:0.39792
# [73]	validation_0-logloss:0.60764	validation_0-error:0.40734	validation_1-logloss:0.60715	validation_1-error:0.39792
# [74]	validation_0-logloss:0.60679	validation_0-error:0.40734	validation_1-logloss:0.60633	validation_1-error:0.39792
# [75]	validation_0-logloss:0.60594	validation_0-error:0.40734	validation_1-logloss:0.60552	validation_1-error:0.39792
# [76]	validation_0-logloss:0.60509	validation_0-error:0.40734	validation_1-logloss:0.60471	validation_1-error:0.39792
# [77]	validation_0-logloss:0.60424	validation_0-error:0.40734	validation_1-logloss:0.60389	validation_1-error:0.39792
# [78]	validation_0-logloss:0.60339	validation_0-error:0.40734	validation_1-logloss:0.60309	validation_1-error:0.39792
# [79]	validation_0-logloss:0.60254	validation_0-error:0.40734	validation_1-logloss:0.60228	validation_1-error:0.39792
# [80]	validation_0-logloss:0.60170	validation_0-error:0.40734	validation_1-logloss:0.60147	validation_1-error:0.39792
# [81]	validation_0-logloss:0.60086	validation_0-error:0.40734	validation_1-logloss:0.60067	validation_1-error:0.39792
# [82]	validation_0-logloss:0.60001	validation_0-error:0.40734	validation_1-logloss:0.59987	validation_1-error:0.39792
# [83]	validation_0-logloss:0.59917	validation_0-error:0.40734	validation_1-logloss:0.59907	validation_1-error:0.39792
# [84]	validation_0-logloss:0.59834	validation_0-error:0.40734	validation_1-logloss:0.59827	validation_1-error:0.39792
# [85]	validation_0-logloss:0.59750	validation_0-error:0.40734	validation_1-logloss:0.59747	validation_1-error:0.39792
# [86]	validation_0-logloss:0.59667	validation_0-error:0.40734	validation_1-logloss:0.59667	validation_1-error:0.39792
# [87]	validation_0-logloss:0.59583	validation_0-error:0.40734	validation_1-logloss:0.59588	validation_1-error:0.39792
# [88]	validation_0-logloss:0.59500	validation_0-error:0.40734	validation_1-logloss:0.59508	validation_1-error:0.39792
# [89]	validation_0-logloss:0.59417	validation_0-error:0.40734	validation_1-logloss:0.59429	validation_1-error:0.39792
# [90]	validation_0-logloss:0.59334	validation_0-error:0.40734	validation_1-logloss:0.59350	validation_1-error:0.39792
# [91]	validation_0-logloss:0.59252	validation_0-error:0.40734	validation_1-logloss:0.59271	validation_1-error:0.39792
# [92]	validation_0-logloss:0.59169	validation_0-error:0.40734	validation_1-logloss:0.59193	validation_1-error:0.39792
# [93]	validation_0-logloss:0.59087	validation_0-error:0.40734	validation_1-logloss:0.59114	validation_1-error:0.39792
# [94]	validation_0-logloss:0.59005	validation_0-error:0.40734	validation_1-logloss:0.59036	validation_1-error:0.39792
# [95]	validation_0-logloss:0.58922	validation_0-error:0.40734	validation_1-logloss:0.58958	validation_1-error:0.39792
# [96]	validation_0-logloss:0.58841	validation_0-error:0.40734	validation_1-logloss:0.58880	validation_1-error:0.39792
# [97]	validation_0-logloss:0.58759	validation_0-error:0.40734	validation_1-logloss:0.58802	validation_1-error:0.39792
# [98]	validation_0-logloss:0.58677	validation_0-error:0.40734	validation_1-logloss:0.58724	validation_1-error:0.39792
# [99]	validation_0-logloss:0.58596	validation_0-error:0.40734	validation_1-logloss:0.58646	validation_1-error:0.39792
# [100]	validation_0-logloss:0.58515	validation_0-error:0.40734	validation_1-logloss:0.58569	validation_1-error:0.39792
# [101]	validation_0-logloss:0.58434	validation_0-error:0.40734	validation_1-logloss:0.58492	validation_1-error:0.39792
# [102]	validation_0-logloss:0.58353	validation_0-error:0.40734	validation_1-logloss:0.58414	validation_1-error:0.39792
# [103]	validation_0-logloss:0.58272	validation_0-error:0.40734	validation_1-logloss:0.58337	validation_1-error:0.39792
# [104]	validation_0-logloss:0.58191	validation_0-error:0.40734	validation_1-logloss:0.58261	validation_1-error:0.39792
# [105]	validation_0-logloss:0.58111	validation_0-error:0.40734	validation_1-logloss:0.58184	validation_1-error:0.39792
# [106]	validation_0-logloss:0.58030	validation_0-error:0.40734	validation_1-logloss:0.58107	validation_1-error:0.39792
# [107]	validation_0-logloss:0.57950	validation_0-error:0.40734	validation_1-logloss:0.58031	validation_1-error:0.39792
# [108]	validation_0-logloss:0.57870	validation_0-error:0.40734	validation_1-logloss:0.57955	validation_1-error:0.39792
# [109]	validation_0-logloss:0.57790	validation_0-error:0.40734	validation_1-logloss:0.57878	validation_1-error:0.39792
# [110]	validation_0-logloss:0.57710	validation_0-error:0.40734	validation_1-logloss:0.57803	validation_1-error:0.39792
# [111]	validation_0-logloss:0.57631	validation_0-error:0.40734	validation_1-logloss:0.57727	validation_1-error:0.39792
# [112]	validation_0-logloss:0.57551	validation_0-error:0.40734	validation_1-logloss:0.57651	validation_1-error:0.39792
# [113]	validation_0-logloss:0.57472	validation_0-error:0.40734	validation_1-logloss:0.57576	validation_1-error:0.39792
# [114]	validation_0-logloss:0.57393	validation_0-error:0.40734	validation_1-logloss:0.57500	validation_1-error:0.39792
# [115]	validation_0-logloss:0.57314	validation_0-error:0.40734	validation_1-logloss:0.57425	validation_1-error:0.39792
# [116]	validation_0-logloss:0.57235	validation_0-error:0.40734	validation_1-logloss:0.57350	validation_1-error:0.39792
# [117]	validation_0-logloss:0.57156	validation_0-error:0.40734	validation_1-logloss:0.57275	validation_1-error:0.39792
# [118]	validation_0-logloss:0.57078	validation_0-error:0.40734	validation_1-logloss:0.57200	validation_1-error:0.39792
# [119]	validation_0-logloss:0.56999	validation_0-error:0.40734	validation_1-logloss:0.57125	validation_1-error:0.39792
# [120]	validation_0-logloss:0.56921	validation_0-error:0.40734	validation_1-logloss:0.57051	validation_1-error:0.39792
# [121]	validation_0-logloss:0.56843	validation_0-error:0.40734	validation_1-logloss:0.56977	validation_1-error:0.39792
# [122]	validation_0-logloss:0.56765	validation_0-error:0.40734	validation_1-logloss:0.56902	validation_1-error:0.39792
# [123]	validation_0-logloss:0.56687	validation_0-error:0.40734	validation_1-logloss:0.56828	validation_1-error:0.39792
# [124]	validation_0-logloss:0.56610	validation_0-error:0.40734	validation_1-logloss:0.56754	validation_1-error:0.39792
# [125]	validation_0-logloss:0.56532	validation_0-error:0.40734	validation_1-logloss:0.56680	validation_1-error:0.39792
# [126]	validation_0-logloss:0.56455	validation_0-error:0.40734	validation_1-logloss:0.56607	validation_1-error:0.39792
# [127]	validation_0-logloss:0.56377	validation_0-error:0.40734	validation_1-logloss:0.56533	validation_1-error:0.39792
# [128]	validation_0-logloss:0.56300	validation_0-error:0.40734	validation_1-logloss:0.56460	validation_1-error:0.39792
# [129]	validation_0-logloss:0.56223	validation_0-error:0.40734	validation_1-logloss:0.56387	validation_1-error:0.39792
# [130]	validation_0-logloss:0.56147	validation_0-error:0.40734	validation_1-logloss:0.56314	validation_1-error:0.39792
# [131]	validation_0-logloss:0.56070	validation_0-error:0.40734	validation_1-logloss:0.56241	validation_1-error:0.39792
# [132]	validation_0-logloss:0.55993	validation_0-error:0.40734	validation_1-logloss:0.56168	validation_1-error:0.39792
# [133]	validation_0-logloss:0.55917	validation_0-error:0.40734	validation_1-logloss:0.56095	validation_1-error:0.39792
# [134]	validation_0-logloss:0.55841	validation_0-error:0.40734	validation_1-logloss:0.56022	validation_1-error:0.39792
# [135]	validation_0-logloss:0.55765	validation_0-error:0.40734	validation_1-logloss:0.55950	validation_1-error:0.39792
# [136]	validation_0-logloss:0.55689	validation_0-error:0.40734	validation_1-logloss:0.55878	validation_1-error:0.39792
# [137]	validation_0-logloss:0.55613	validation_0-error:0.40734	validation_1-logloss:0.55806	validation_1-error:0.39792
# [138]	validation_0-logloss:0.55537	validation_0-error:0.40734	validation_1-logloss:0.55734	validation_1-error:0.39792
# [139]	validation_0-logloss:0.55462	validation_0-error:0.40734	validation_1-logloss:0.55662	validation_1-error:0.39792
# [140]	validation_0-logloss:0.55386	validation_0-error:0.40734	validation_1-logloss:0.55590	validation_1-error:0.39792
# [141]	validation_0-logloss:0.55311	validation_0-error:0.40734	validation_1-logloss:0.55518	validation_1-error:0.39792
# [142]	validation_0-logloss:0.55236	validation_0-error:0.40734	validation_1-logloss:0.55447	validation_1-error:0.39792
# [143]	validation_0-logloss:0.55161	validation_0-error:0.40734	validation_1-logloss:0.55376	validation_1-error:0.39792
# [144]	validation_0-logloss:0.55086	validation_0-error:0.40734	validation_1-logloss:0.55304	validation_1-error:0.39792
# [145]	validation_0-logloss:0.55011	validation_0-error:0.40734	validation_1-logloss:0.55233	validation_1-error:0.39792
# [146]	validation_0-logloss:0.54937	validation_0-error:0.40734	validation_1-logloss:0.55162	validation_1-error:0.39792
# [147]	validation_0-logloss:0.54862	validation_0-error:0.40734	validation_1-logloss:0.55092	validation_1-error:0.39792
# [148]	validation_0-logloss:0.54788	validation_0-error:0.40734	validation_1-logloss:0.55021	validation_1-error:0.39792
# [149]	validation_0-logloss:0.54714	validation_0-error:0.40734	validation_1-logloss:0.54950	validation_1-error:0.39792
# [150]	validation_0-logloss:0.54640	validation_0-error:0.40734	validation_1-logloss:0.54880	validation_1-error:0.39792
# [151]	validation_0-logloss:0.54566	validation_0-error:0.40734	validation_1-logloss:0.54810	validation_1-error:0.39792
# [152]	validation_0-logloss:0.54492	validation_0-error:0.40734	validation_1-logloss:0.54740	validation_1-error:0.39792
# [153]	validation_0-logloss:0.54418	validation_0-error:0.40734	validation_1-logloss:0.54670	validation_1-error:0.39792
# [154]	validation_0-logloss:0.54345	validation_0-error:0.40734	validation_1-logloss:0.54600	validation_1-error:0.39792
# [155]	validation_0-logloss:0.54271	validation_0-error:0.40734	validation_1-logloss:0.54530	validation_1-error:0.39792
# [156]	validation_0-logloss:0.54198	validation_0-error:0.40734	validation_1-logloss:0.54460	validation_1-error:0.39792
# [157]	validation_0-logloss:0.54125	validation_0-error:0.40734	validation_1-logloss:0.54391	validation_1-error:0.39792
# [158]	validation_0-logloss:0.54052	validation_0-error:0.40734	validation_1-logloss:0.54321	validation_1-error:0.39792
# [159]	validation_0-logloss:0.53979	validation_0-error:0.40734	validation_1-logloss:0.54252	validation_1-error:0.39792
# [160]	validation_0-logloss:0.53906	validation_0-error:0.40734	validation_1-logloss:0.54183	validation_1-error:0.39792
# [161]	validation_0-logloss:0.53834	validation_0-error:0.40734	validation_1-logloss:0.54114	validation_1-error:0.39792
# [162]	validation_0-logloss:0.53761	validation_0-error:0.40734	validation_1-logloss:0.54045	validation_1-error:0.39792
# [163]	validation_0-logloss:0.53689	validation_0-error:0.40734	validation_1-logloss:0.53977	validation_1-error:0.39792
# [164]	validation_0-logloss:0.53617	validation_0-error:0.40734	validation_1-logloss:0.53908	validation_1-error:0.39792
# [165]	validation_0-logloss:0.53545	validation_0-error:0.40734	validation_1-logloss:0.53840	validation_1-error:0.39792
# [166]	validation_0-logloss:0.53473	validation_0-error:0.40734	validation_1-logloss:0.53771	validation_1-error:0.39792
# [167]	validation_0-logloss:0.53401	validation_0-error:0.40734	validation_1-logloss:0.53703	validation_1-error:0.39792
# [168]	validation_0-logloss:0.53329	validation_0-error:0.40734	validation_1-logloss:0.53635	validation_1-error:0.39792
# [169]	validation_0-logloss:0.53258	validation_0-error:0.00000	validation_1-logloss:0.53567	validation_1-error:0.02076
# [170]	validation_0-logloss:0.53186	validation_0-error:0.00000	validation_1-logloss:0.53499	validation_1-error:0.02076
# [171]	validation_0-logloss:0.53115	validation_0-error:0.00000	validation_1-logloss:0.53431	validation_1-error:0.02076
# [172]	validation_0-logloss:0.53044	validation_0-error:0.00000	validation_1-logloss:0.53364	validation_1-error:0.02076
# [173]	validation_0-logloss:0.52973	validation_0-error:0.00000	validation_1-logloss:0.53296	validation_1-error:0.02076
# [174]	validation_0-logloss:0.52902	validation_0-error:0.00000	validation_1-logloss:0.53229	validation_1-error:0.02076
# [175]	validation_0-logloss:0.52831	validation_0-error:0.00000	validation_1-logloss:0.53162	validation_1-error:0.02076
# [176]	validation_0-logloss:0.52760	validation_0-error:0.00000	validation_1-logloss:0.53095	validation_1-error:0.02076
# [177]	validation_0-logloss:0.52690	validation_0-error:0.00000	validation_1-logloss:0.53028	validation_1-error:0.02076
# [178]	validation_0-logloss:0.52619	validation_0-error:0.00000	validation_1-logloss:0.52961	validation_1-error:0.02076
# [179]	validation_0-logloss:0.52549	validation_0-error:0.00000	validation_1-logloss:0.52894	validation_1-error:0.02076
# [180]	validation_0-logloss:0.52479	validation_0-error:0.00000	validation_1-logloss:0.52827	validation_1-error:0.02076
# [181]	validation_0-logloss:0.52409	validation_0-error:0.00000	validation_1-logloss:0.52761	validation_1-error:0.02076
# [182]	validation_0-logloss:0.52339	validation_0-error:0.00000	validation_1-logloss:0.52695	validation_1-error:0.02076
# [183]	validation_0-logloss:0.52269	validation_0-error:0.00000	validation_1-logloss:0.52628	validation_1-error:0.02076
# [184]	validation_0-logloss:0.52199	validation_0-error:0.00000	validation_1-logloss:0.52562	validation_1-error:0.02076
# [185]	validation_0-logloss:0.52130	validation_0-error:0.00000	validation_1-logloss:0.52496	validation_1-error:0.02076
# [186]	validation_0-logloss:0.52060	validation_0-error:0.00000	validation_1-logloss:0.52430	validation_1-error:0.02076
# [187]	validation_0-logloss:0.51991	validation_0-error:0.00000	validation_1-logloss:0.52365	validation_1-error:0.02076
# [188]	validation_0-logloss:0.51922	validation_0-error:0.00000	validation_1-logloss:0.52299	validation_1-error:0.02076
# [189]	validation_0-logloss:0.51853	validation_0-error:0.00000	validation_1-logloss:0.52233	validation_1-error:0.02076
# [190]	validation_0-logloss:0.51784	validation_0-error:0.00000	validation_1-logloss:0.52168	validation_1-error:0.02076
# [191]	validation_0-logloss:0.51715	validation_0-error:0.00000	validation_1-logloss:0.52103	validation_1-error:0.02076
# [192]	validation_0-logloss:0.51646	validation_0-error:0.00000	validation_1-logloss:0.52038	validation_1-error:0.02076
# [193]	validation_0-logloss:0.51578	validation_0-error:0.00000	validation_1-logloss:0.51973	validation_1-error:0.02076
# [194]	validation_0-logloss:0.51509	validation_0-error:0.00000	validation_1-logloss:0.51908	validation_1-error:0.02076
# [195]	validation_0-logloss:0.51441	validation_0-error:0.00000	validation_1-logloss:0.51843	validation_1-error:0.02076
# [196]	validation_0-logloss:0.51373	validation_0-error:0.00000	validation_1-logloss:0.51778	validation_1-error:0.02076
# [197]	validation_0-logloss:0.51305	validation_0-error:0.00000	validation_1-logloss:0.51713	validation_1-error:0.02076
# [198]	validation_0-logloss:0.51237	validation_0-error:0.00000	validation_1-logloss:0.51649	validation_1-error:0.02076
# [199]	validation_0-logloss:0.51169	validation_0-error:0.00000	validation_1-logloss:0.51585	validation_1-error:0.02076
# [200]	validation_0-logloss:0.51101	validation_0-error:0.00000	validation_1-logloss:0.51520	validation_1-error:0.02076
# [201]	validation_0-logloss:0.51033	validation_0-error:0.00000	validation_1-logloss:0.51456	validation_1-error:0.02076
# [202]	validation_0-logloss:0.50966	validation_0-error:0.00000	validation_1-logloss:0.51392	validation_1-error:0.02076
# [203]	validation_0-logloss:0.50898	validation_0-error:0.00000	validation_1-logloss:0.51328	validation_1-error:0.02076
# [204]	validation_0-logloss:0.50831	validation_0-error:0.00000	validation_1-logloss:0.51265	validation_1-error:0.02076
# [205]	validation_0-logloss:0.50764	validation_0-error:0.00000	validation_1-logloss:0.51201	validation_1-error:0.02076
# [206]	validation_0-logloss:0.50697	validation_0-error:0.00000	validation_1-logloss:0.51137	validation_1-error:0.02076
# [207]	validation_0-logloss:0.50630	validation_0-error:0.00000	validation_1-logloss:0.51074	validation_1-error:0.02076
# [208]	validation_0-logloss:0.50563	validation_0-error:0.00000	validation_1-logloss:0.51011	validation_1-error:0.02076
# [209]	validation_0-logloss:0.50497	validation_0-error:0.00000	validation_1-logloss:0.50947	validation_1-error:0.02076
# [210]	validation_0-logloss:0.50430	validation_0-error:0.00000	validation_1-logloss:0.50884	validation_1-error:0.02076
# [211]	validation_0-logloss:0.50363	validation_0-error:0.00000	validation_1-logloss:0.50821	validation_1-error:0.02076
# [212]	validation_0-logloss:0.50297	validation_0-error:0.00000	validation_1-logloss:0.50758	validation_1-error:0.02076
# [213]	validation_0-logloss:0.50231	validation_0-error:0.00000	validation_1-logloss:0.50696	validation_1-error:0.02076
# [214]	validation_0-logloss:0.50165	validation_0-error:0.00000	validation_1-logloss:0.50633	validation_1-error:0.02076
# [215]	validation_0-logloss:0.50099	validation_0-error:0.00000	validation_1-logloss:0.50570	validation_1-error:0.02076
# [216]	validation_0-logloss:0.50033	validation_0-error:0.00000	validation_1-logloss:0.50508	validation_1-error:0.02076
# [217]	validation_0-logloss:0.49967	validation_0-error:0.00000	validation_1-logloss:0.50446	validation_1-error:0.02076
# [218]	validation_0-logloss:0.49901	validation_0-error:0.00000	validation_1-logloss:0.50384	validation_1-error:0.02076
# [219]	validation_0-logloss:0.49836	validation_0-error:0.00000	validation_1-logloss:0.50321	validation_1-error:0.02076
# [220]	validation_0-logloss:0.49770	validation_0-error:0.00000	validation_1-logloss:0.50259	validation_1-error:0.02076
# [221]	validation_0-logloss:0.49705	validation_0-error:0.00000	validation_1-logloss:0.50198	validation_1-error:0.02076
# [222]	validation_0-logloss:0.49640	validation_0-error:0.00000	validation_1-logloss:0.50136	validation_1-error:0.02076
# [223]	validation_0-logloss:0.49575	validation_0-error:0.00000	validation_1-logloss:0.50074	validation_1-error:0.02076
# [224]	validation_0-logloss:0.49510	validation_0-error:0.00000	validation_1-logloss:0.50013	validation_1-error:0.02076
# [225]	validation_0-logloss:0.49445	validation_0-error:0.00000	validation_1-logloss:0.49951	validation_1-error:0.02076
# [226]	validation_0-logloss:0.49380	validation_0-error:0.00000	validation_1-logloss:0.49890	validation_1-error:0.02076
# [227]	validation_0-logloss:0.49315	validation_0-error:0.00000	validation_1-logloss:0.49829	validation_1-error:0.02076
# [228]	validation_0-logloss:0.49251	validation_0-error:0.00000	validation_1-logloss:0.49767	validation_1-error:0.02076
# [229]	validation_0-logloss:0.49186	validation_0-error:0.00000	validation_1-logloss:0.49706	validation_1-error:0.02076
# [230]	validation_0-logloss:0.49122	validation_0-error:0.00000	validation_1-logloss:0.49646	validation_1-error:0.02076
# [231]	validation_0-logloss:0.49058	validation_0-error:0.00000	validation_1-logloss:0.49585	validation_1-error:0.02076
# [232]	validation_0-logloss:0.48994	validation_0-error:0.00000	validation_1-logloss:0.49524	validation_1-error:0.02076
# [233]	validation_0-logloss:0.48930	validation_0-error:0.00000	validation_1-logloss:0.49463	validation_1-error:0.02076
# [234]	validation_0-logloss:0.48866	validation_0-error:0.00000	validation_1-logloss:0.49403	validation_1-error:0.02076
# [235]	validation_0-logloss:0.48802	validation_0-error:0.00000	validation_1-logloss:0.49343	validation_1-error:0.02076
# [236]	validation_0-logloss:0.48738	validation_0-error:0.00000	validation_1-logloss:0.49282	validation_1-error:0.02076
# [237]	validation_0-logloss:0.48675	validation_0-error:0.00000	validation_1-logloss:0.49222	validation_1-error:0.02076
# [238]	validation_0-logloss:0.48611	validation_0-error:0.00000	validation_1-logloss:0.49162	validation_1-error:0.02076
# [239]	validation_0-logloss:0.48548	validation_0-error:0.00000	validation_1-logloss:0.49102	validation_1-error:0.02076
# [240]	validation_0-logloss:0.48485	validation_0-error:0.00000	validation_1-logloss:0.49042	validation_1-error:0.02076
# [241]	validation_0-logloss:0.48421	validation_0-error:0.00000	validation_1-logloss:0.48983	validation_1-error:0.02076
# [242]	validation_0-logloss:0.48358	validation_0-error:0.00000	validation_1-logloss:0.48923	validation_1-error:0.02076
# [243]	validation_0-logloss:0.48295	validation_0-error:0.00000	validation_1-logloss:0.48863	validation_1-error:0.02076
# [244]	validation_0-logloss:0.48233	validation_0-error:0.00000	validation_1-logloss:0.48804	validation_1-error:0.02076
# [245]	validation_0-logloss:0.48170	validation_0-error:0.00000	validation_1-logloss:0.48745	validation_1-error:0.02076
# [246]	validation_0-logloss:0.48107	validation_0-error:0.00000	validation_1-logloss:0.48685	validation_1-error:0.02076
# [247]	validation_0-logloss:0.48045	validation_0-error:0.00000	validation_1-logloss:0.48626	validation_1-error:0.02076
# [248]	validation_0-logloss:0.47982	validation_0-error:0.00000	validation_1-logloss:0.48567	validation_1-error:0.02076
# [249]	validation_0-logloss:0.47920	validation_0-error:0.00000	validation_1-logloss:0.48508	validation_1-error:0.02076
# [250]	validation_0-logloss:0.47858	validation_0-error:0.00000	validation_1-logloss:0.48450	validation_1-error:0.02076
# [251]	validation_0-logloss:0.47796	validation_0-error:0.00000	validation_1-logloss:0.48391	validation_1-error:0.02076
# [252]	validation_0-logloss:0.47734	validation_0-error:0.00000	validation_1-logloss:0.48332	validation_1-error:0.02076
# [253]	validation_0-logloss:0.47672	validation_0-error:0.00000	validation_1-logloss:0.48274	validation_1-error:0.02076
# [254]	validation_0-logloss:0.47610	validation_0-error:0.00000	validation_1-logloss:0.48215	validation_1-error:0.02076
# [255]	validation_0-logloss:0.47548	validation_0-error:0.00000	validation_1-logloss:0.48157	validation_1-error:0.02076
# [256]	validation_0-logloss:0.47487	validation_0-error:0.00000	validation_1-logloss:0.48099	validation_1-error:0.02076
# [257]	validation_0-logloss:0.47425	validation_0-error:0.00000	validation_1-logloss:0.48041	validation_1-error:0.02076
# [258]	validation_0-logloss:0.47364	validation_0-error:0.00000	validation_1-logloss:0.47983	validation_1-error:0.02076
# [259]	validation_0-logloss:0.47303	validation_0-error:0.00000	validation_1-logloss:0.47925	validation_1-error:0.02076
# [260]	validation_0-logloss:0.47241	validation_0-error:0.00000	validation_1-logloss:0.47867	validation_1-error:0.02076
# [261]	validation_0-logloss:0.47180	validation_0-error:0.00000	validation_1-logloss:0.47809	validation_1-error:0.02076
# [262]	validation_0-logloss:0.47119	validation_0-error:0.00000	validation_1-logloss:0.47752	validation_1-error:0.02076
# [263]	validation_0-logloss:0.47058	validation_0-error:0.00000	validation_1-logloss:0.47694	validation_1-error:0.02076
# [264]	validation_0-logloss:0.46998	validation_0-error:0.00000	validation_1-logloss:0.47637	validation_1-error:0.02076
# [265]	validation_0-logloss:0.46937	validation_0-error:0.00000	validation_1-logloss:0.47580	validation_1-error:0.02076
# [266]	validation_0-logloss:0.46876	validation_0-error:0.00000	validation_1-logloss:0.47522	validation_1-error:0.02076
# [267]	validation_0-logloss:0.46816	validation_0-error:0.00000	validation_1-logloss:0.47465	validation_1-error:0.02076
# [268]	validation_0-logloss:0.46756	validation_0-error:0.00000	validation_1-logloss:0.47408	validation_1-error:0.02076
# [269]	validation_0-logloss:0.46695	validation_0-error:0.00000	validation_1-logloss:0.47351	validation_1-error:0.02076
# [270]	validation_0-logloss:0.46635	validation_0-error:0.00000	validation_1-logloss:0.47294	validation_1-error:0.02076
# [271]	validation_0-logloss:0.46575	validation_0-error:0.00000	validation_1-logloss:0.47238	validation_1-error:0.02076
# [272]	validation_0-logloss:0.46515	validation_0-error:0.00000	validation_1-logloss:0.47181	validation_1-error:0.02076
# [273]	validation_0-logloss:0.46455	validation_0-error:0.00000	validation_1-logloss:0.47125	validation_1-error:0.02076
# [274]	validation_0-logloss:0.46396	validation_0-error:0.00000	validation_1-logloss:0.47068	validation_1-error:0.02076
# [275]	validation_0-logloss:0.46336	validation_0-error:0.00000	validation_1-logloss:0.47012	validation_1-error:0.02076
# [276]	validation_0-logloss:0.46276	validation_0-error:0.00000	validation_1-logloss:0.46956	validation_1-error:0.02076
# [277]	validation_0-logloss:0.46217	validation_0-error:0.00000	validation_1-logloss:0.46899	validation_1-error:0.02076
# [278]	validation_0-logloss:0.46157	validation_0-error:0.00000	validation_1-logloss:0.46843	validation_1-error:0.02076
# [279]	validation_0-logloss:0.46098	validation_0-error:0.00000	validation_1-logloss:0.46787	validation_1-error:0.02076
# [280]	validation_0-logloss:0.46039	validation_0-error:0.00000	validation_1-logloss:0.46732	validation_1-error:0.02076
# [281]	validation_0-logloss:0.45980	validation_0-error:0.00000	validation_1-logloss:0.46676	validation_1-error:0.02076
# [282]	validation_0-logloss:0.45921	validation_0-error:0.00000	validation_1-logloss:0.46620	validation_1-error:0.02076
# [283]	validation_0-logloss:0.45862	validation_0-error:0.00000	validation_1-logloss:0.46565	validation_1-error:0.02076
# [284]	validation_0-logloss:0.45803	validation_0-error:0.00000	validation_1-logloss:0.46509	validation_1-error:0.02076
# [285]	validation_0-logloss:0.45744	validation_0-error:0.00000	validation_1-logloss:0.46454	validation_1-error:0.02076
# [286]	validation_0-logloss:0.45686	validation_0-error:0.00000	validation_1-logloss:0.46398	validation_1-error:0.02076
# [287]	validation_0-logloss:0.45627	validation_0-error:0.00000	validation_1-logloss:0.46343	validation_1-error:0.02076
# [288]	validation_0-logloss:0.45569	validation_0-error:0.00000	validation_1-logloss:0.46288	validation_1-error:0.02076
# [289]	validation_0-logloss:0.45511	validation_0-error:0.00000	validation_1-logloss:0.46233	validation_1-error:0.02076
# [290]	validation_0-logloss:0.45452	validation_0-error:0.00000	validation_1-logloss:0.46178	validation_1-error:0.02076
# [291]	validation_0-logloss:0.45394	validation_0-error:0.00000	validation_1-logloss:0.46123	validation_1-error:0.02076
# [292]	validation_0-logloss:0.45336	validation_0-error:0.00000	validation_1-logloss:0.46069	validation_1-error:0.02076
# [293]	validation_0-logloss:0.45278	validation_0-error:0.00000	validation_1-logloss:0.46014	validation_1-error:0.02076
# [294]	validation_0-logloss:0.45220	validation_0-error:0.00000	validation_1-logloss:0.45960	validation_1-error:0.02076
# [295]	validation_0-logloss:0.45163	validation_0-error:0.00000	validation_1-logloss:0.45905	validation_1-error:0.02076
# [296]	validation_0-logloss:0.45105	validation_0-error:0.00000	validation_1-logloss:0.45851	validation_1-error:0.02076
# [297]	validation_0-logloss:0.45048	validation_0-error:0.00000	validation_1-logloss:0.45796	validation_1-error:0.02076
# [298]	validation_0-logloss:0.44990	validation_0-error:0.00000	validation_1-logloss:0.45742	validation_1-error:0.02076
# [299]	validation_0-logloss:0.44933	validation_0-error:0.00000	validation_1-logloss:0.45688	validation_1-error:0.02076
# [300]	validation_0-logloss:0.44875	validation_0-error:0.00000	validation_1-logloss:0.45634	validation_1-error:0.02076
# [301]	validation_0-logloss:0.44818	validation_0-error:0.00000	validation_1-logloss:0.45580	validation_1-error:0.02076
# [302]	validation_0-logloss:0.44761	validation_0-error:0.00000	validation_1-logloss:0.45526	validation_1-error:0.02076
# [303]	validation_0-logloss:0.44704	validation_0-error:0.00000	validation_1-logloss:0.45473	validation_1-error:0.02076
# [304]	validation_0-logloss:0.44647	validation_0-error:0.00000	validation_1-logloss:0.45419	validation_1-error:0.02076
# [305]	validation_0-logloss:0.44590	validation_0-error:0.00000	validation_1-logloss:0.45366	validation_1-error:0.02076
# [306]	validation_0-logloss:0.44534	validation_0-error:0.00000	validation_1-logloss:0.45312	validation_1-error:0.02076
# [307]	validation_0-logloss:0.44477	validation_0-error:0.00000	validation_1-logloss:0.45259	validation_1-error:0.02076
# [308]	validation_0-logloss:0.44420	validation_0-error:0.00000	validation_1-logloss:0.45205	validation_1-error:0.02076
# [309]	validation_0-logloss:0.44364	validation_0-error:0.00000	validation_1-logloss:0.45152	validation_1-error:0.02076
# [310]	validation_0-logloss:0.44308	validation_0-error:0.00000	validation_1-logloss:0.45099	validation_1-error:0.02076
# [311]	validation_0-logloss:0.44251	validation_0-error:0.00000	validation_1-logloss:0.45046	validation_1-error:0.02076
# [312]	validation_0-logloss:0.44195	validation_0-error:0.00000	validation_1-logloss:0.44993	validation_1-error:0.02076
# [313]	validation_0-logloss:0.44139	validation_0-error:0.00000	validation_1-logloss:0.44940	validation_1-error:0.02076
# [314]	validation_0-logloss:0.44083	validation_0-error:0.00000	validation_1-logloss:0.44888	validation_1-error:0.02076
# [315]	validation_0-logloss:0.44027	validation_0-error:0.00000	validation_1-logloss:0.44835	validation_1-error:0.02076
# [316]	validation_0-logloss:0.43971	validation_0-error:0.00000	validation_1-logloss:0.44782	validation_1-error:0.02076
# [317]	validation_0-logloss:0.43916	validation_0-error:0.00000	validation_1-logloss:0.44730	validation_1-error:0.02076
# [318]	validation_0-logloss:0.43860	validation_0-error:0.00000	validation_1-logloss:0.44678	validation_1-error:0.02076
# [319]	validation_0-logloss:0.43804	validation_0-error:0.00000	validation_1-logloss:0.44625	validation_1-error:0.02076
# [320]	validation_0-logloss:0.43749	validation_0-error:0.00000	validation_1-logloss:0.44573	validation_1-error:0.02076
# [321]	validation_0-logloss:0.43694	validation_0-error:0.00000	validation_1-logloss:0.44521	validation_1-error:0.02076
# [322]	validation_0-logloss:0.43638	validation_0-error:0.00000	validation_1-logloss:0.44469	validation_1-error:0.02076
# [323]	validation_0-logloss:0.43583	validation_0-error:0.00000	validation_1-logloss:0.44417	validation_1-error:0.02076
# [324]	validation_0-logloss:0.43528	validation_0-error:0.00000	validation_1-logloss:0.44365	validation_1-error:0.02076
# [325]	validation_0-logloss:0.43473	validation_0-error:0.00000	validation_1-logloss:0.44313	validation_1-error:0.02076
# [326]	validation_0-logloss:0.43418	validation_0-error:0.00000	validation_1-logloss:0.44261	validation_1-error:0.02076
# [327]	validation_0-logloss:0.43363	validation_0-error:0.00000	validation_1-logloss:0.44210	validation_1-error:0.02076
# [328]	validation_0-logloss:0.43308	validation_0-error:0.00000	validation_1-logloss:0.44158	validation_1-error:0.02076
# [329]	validation_0-logloss:0.43254	validation_0-error:0.00000	validation_1-logloss:0.44107	validation_1-error:0.02076
# [330]	validation_0-logloss:0.43199	validation_0-error:0.00000	validation_1-logloss:0.44056	validation_1-error:0.02076
# [331]	validation_0-logloss:0.43145	validation_0-error:0.00000	validation_1-logloss:0.44004	validation_1-error:0.02076
# [332]	validation_0-logloss:0.43090	validation_0-error:0.00000	validation_1-logloss:0.43953	validation_1-error:0.02076
# [333]	validation_0-logloss:0.43036	validation_0-error:0.00000	validation_1-logloss:0.43902	validation_1-error:0.02076
# [334]	validation_0-logloss:0.42982	validation_0-error:0.00000	validation_1-logloss:0.43851	validation_1-error:0.02076
# [335]	validation_0-logloss:0.42927	validation_0-error:0.00000	validation_1-logloss:0.43800	validation_1-error:0.02076
# [336]	validation_0-logloss:0.42873	validation_0-error:0.00000	validation_1-logloss:0.43749	validation_1-error:0.02076
# [337]	validation_0-logloss:0.42819	validation_0-error:0.00000	validation_1-logloss:0.43698	validation_1-error:0.02076
# [338]	validation_0-logloss:0.42765	validation_0-error:0.00000	validation_1-logloss:0.43648	validation_1-error:0.02076
# [339]	validation_0-logloss:0.42712	validation_0-error:0.00000	validation_1-logloss:0.43597	validation_1-error:0.02076
# [340]	validation_0-logloss:0.42658	validation_0-error:0.00000	validation_1-logloss:0.43547	validation_1-error:0.02076
# [341]	validation_0-logloss:0.42604	validation_0-error:0.00000	validation_1-logloss:0.43496	validation_1-error:0.02076
# [342]	validation_0-logloss:0.42551	validation_0-error:0.00000	validation_1-logloss:0.43446	validation_1-error:0.02076
# [343]	validation_0-logloss:0.42497	validation_0-error:0.00000	validation_1-logloss:0.43395	validation_1-error:0.02076
# [344]	validation_0-logloss:0.42444	validation_0-error:0.00000	validation_1-logloss:0.43345	validation_1-error:0.02076
# [345]	validation_0-logloss:0.42390	validation_0-error:0.00000	validation_1-logloss:0.43295	validation_1-error:0.02076
# [346]	validation_0-logloss:0.42337	validation_0-error:0.00000	validation_1-logloss:0.43245	validation_1-error:0.02076
# [347]	validation_0-logloss:0.42284	validation_0-error:0.00000	validation_1-logloss:0.43195	validation_1-error:0.02076
# [348]	validation_0-logloss:0.42231	validation_0-error:0.00000	validation_1-logloss:0.43145	validation_1-error:0.02076
# [349]	validation_0-logloss:0.42178	validation_0-error:0.00000	validation_1-logloss:0.43096	validation_1-error:0.02076
# [350]	validation_0-logloss:0.42125	validation_0-error:0.00000	validation_1-logloss:0.43046	validation_1-error:0.02076
# [351]	validation_0-logloss:0.42072	validation_0-error:0.00000	validation_1-logloss:0.42996	validation_1-error:0.02076
# [352]	validation_0-logloss:0.42020	validation_0-error:0.00000	validation_1-logloss:0.42947	validation_1-error:0.02076
# [353]	validation_0-logloss:0.41967	validation_0-error:0.00000	validation_1-logloss:0.42897	validation_1-error:0.02076
# [354]	validation_0-logloss:0.41914	validation_0-error:0.00000	validation_1-logloss:0.42848	validation_1-error:0.02076
# [355]	validation_0-logloss:0.41862	validation_0-error:0.00000	validation_1-logloss:0.42799	validation_1-error:0.02076
# [356]	validation_0-logloss:0.41810	validation_0-error:0.00000	validation_1-logloss:0.42749	validation_1-error:0.02076
# [357]	validation_0-logloss:0.41757	validation_0-error:0.00000	validation_1-logloss:0.42700	validation_1-error:0.02076
# [358]	validation_0-logloss:0.41705	validation_0-error:0.00000	validation_1-logloss:0.42651	validation_1-error:0.02076
# [359]	validation_0-logloss:0.41653	validation_0-error:0.00000	validation_1-logloss:0.42602	validation_1-error:0.02076
# [360]	validation_0-logloss:0.41601	validation_0-error:0.00000	validation_1-logloss:0.42553	validation_1-error:0.02076
# [361]	validation_0-logloss:0.41549	validation_0-error:0.00000	validation_1-logloss:0.42504	validation_1-error:0.02076
# [362]	validation_0-logloss:0.41497	validation_0-error:0.00000	validation_1-logloss:0.42456	validation_1-error:0.02076
# [363]	validation_0-logloss:0.41445	validation_0-error:0.00000	validation_1-logloss:0.42407	validation_1-error:0.02076
# [364]	validation_0-logloss:0.41393	validation_0-error:0.00000	validation_1-logloss:0.42358	validation_1-error:0.02076
# [365]	validation_0-logloss:0.41342	validation_0-error:0.00000	validation_1-logloss:0.42310	validation_1-error:0.02076
# [366]	validation_0-logloss:0.41290	validation_0-error:0.00000	validation_1-logloss:0.42262	validation_1-error:0.02076
# [367]	validation_0-logloss:0.41239	validation_0-error:0.00000	validation_1-logloss:0.42213	validation_1-error:0.02076
# [368]	validation_0-logloss:0.41187	validation_0-error:0.00000	validation_1-logloss:0.42165	validation_1-error:0.02076
# [369]	validation_0-logloss:0.41136	validation_0-error:0.00000	validation_1-logloss:0.42117	validation_1-error:0.02076
# [370]	validation_0-logloss:0.41084	validation_0-error:0.00000	validation_1-logloss:0.42069	validation_1-error:0.02076
# [371]	validation_0-logloss:0.41033	validation_0-error:0.00000	validation_1-logloss:0.42021	validation_1-error:0.02076
# [372]	validation_0-logloss:0.40982	validation_0-error:0.00000	validation_1-logloss:0.41973	validation_1-error:0.02076
# [373]	validation_0-logloss:0.40931	validation_0-error:0.00000	validation_1-logloss:0.41925	validation_1-error:0.02076
# [374]	validation_0-logloss:0.40880	validation_0-error:0.00000	validation_1-logloss:0.41877	validation_1-error:0.02076
# [375]	validation_0-logloss:0.40829	validation_0-error:0.00000	validation_1-logloss:0.41829	validation_1-error:0.02076
# [376]	validation_0-logloss:0.40779	validation_0-error:0.00000	validation_1-logloss:0.41782	validation_1-error:0.02076
# [377]	validation_0-logloss:0.40728	validation_0-error:0.00000	validation_1-logloss:0.41734	validation_1-error:0.02076
# [378]	validation_0-logloss:0.40677	validation_0-error:0.00000	validation_1-logloss:0.41687	validation_1-error:0.02076
# [379]	validation_0-logloss:0.40627	validation_0-error:0.00000	validation_1-logloss:0.41639	validation_1-error:0.02076
# [380]	validation_0-logloss:0.40576	validation_0-error:0.00000	validation_1-logloss:0.41592	validation_1-error:0.02076
# [381]	validation_0-logloss:0.40526	validation_0-error:0.00000	validation_1-logloss:0.41544	validation_1-error:0.02076
# [382]	validation_0-logloss:0.40475	validation_0-error:0.00000	validation_1-logloss:0.41497	validation_1-error:0.02076
# [383]	validation_0-logloss:0.40425	validation_0-error:0.00000	validation_1-logloss:0.41450	validation_1-error:0.02076
# [384]	validation_0-logloss:0.40375	validation_0-error:0.00000	validation_1-logloss:0.41403	validation_1-error:0.02076
# [385]	validation_0-logloss:0.40325	validation_0-error:0.00000	validation_1-logloss:0.41356	validation_1-error:0.02076
# [386]	validation_0-logloss:0.40275	validation_0-error:0.00000	validation_1-logloss:0.41309	validation_1-error:0.02076
# [387]	validation_0-logloss:0.40225	validation_0-error:0.00000	validation_1-logloss:0.41262	validation_1-error:0.02076
# [388]	validation_0-logloss:0.40175	validation_0-error:0.00000	validation_1-logloss:0.41216	validation_1-error:0.02076
# [389]	validation_0-logloss:0.40125	validation_0-error:0.00000	validation_1-logloss:0.41169	validation_1-error:0.02076
# [390]	validation_0-logloss:0.40076	validation_0-error:0.00000	validation_1-logloss:0.41123	validation_1-error:0.02076
# [391]	validation_0-logloss:0.40026	validation_0-error:0.00000	validation_1-logloss:0.41076	validation_1-error:0.02076
# [392]	validation_0-logloss:0.39976	validation_0-error:0.00000	validation_1-logloss:0.41030	validation_1-error:0.02076
# [393]	validation_0-logloss:0.39927	validation_0-error:0.00000	validation_1-logloss:0.40983	validation_1-error:0.02076
# [394]	validation_0-logloss:0.39878	validation_0-error:0.00000	validation_1-logloss:0.40937	validation_1-error:0.02076
# [395]	validation_0-logloss:0.39828	validation_0-error:0.00000	validation_1-logloss:0.40891	validation_1-error:0.02076
# [396]	validation_0-logloss:0.39779	validation_0-error:0.00000	validation_1-logloss:0.40845	validation_1-error:0.02076
# [397]	validation_0-logloss:0.39730	validation_0-error:0.00000	validation_1-logloss:0.40798	validation_1-error:0.02076
# [398]	validation_0-logloss:0.39681	validation_0-error:0.00000	validation_1-logloss:0.40752	validation_1-error:0.02076
# [399]	validation_0-logloss:0.39632	validation_0-error:0.00000	validation_1-logloss:0.40707	validation_1-error:0.02076
# Accuracy: 0.9973985431841832
# F1 Score: 0.9973066588865263
# Precision: 0.9968193384223918
# Recall: 0.9978089395267309
# ROC AUC: 0.997808939526731

# %% [markdown]
# #  Multi-Model Ensemble (VGG16 + ResNet50 + RF + SVM + Logistic Regression + XGBoost)

# %%
import os
import numpy as np
import cv2
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
import xgboost as xgb
from tensorflow.keras.applications import VGG16, ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_dir = '/kaggle/input/pcos-detection-using-ultrasound-images/data/train'
test_dir = '/kaggle/input/pcos-detection-using-ultrasound-images/data/test'
image_size = (224, 224)

def load_images_from_folder(base_dir):
    images, labels = [], []
    classes = {'infected': 1, 'notinfected': 0}
    for label in classes:
        folder_path = os.path.join(base_dir, label)
        for image_file in os.listdir(folder_path):
            img_path = os.path.join(folder_path, image_file)
            img = cv2.imread(img_path)
            if img is not None:
                img = cv2.resize(img, image_size)
                images.append(img)
                labels.append(classes[label])
    return np.array(images), np.array(labels)


train_images, train_labels = load_images_from_folder(train_dir)
test_images, test_labels = load_images_from_folder(test_dir)
train_images = train_images / 255.0
test_images = test_images / 255.0

X_train, X_val, y_train, y_val = train_test_split(train_images, train_labels, test_size=0.15, random_state=42)


datagen = ImageDataGenerator(rotation_range=20, zoom_range=0.15, width_shift_range=0.2,
                             height_shift_range=0.2, shear_range=0.15, horizontal_flip=True, fill_mode="nearest")
datagen.fit(X_train)

# Feature extraction with VGG16
vgg_model = VGG16(weights='/kaggle/input/vggnet16/keras/default/1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5',
                  include_top=False, input_shape=(224, 224, 3))
vgg_output = GlobalAveragePooling2D()(vgg_model.output)
vgg_feature_extractor = Model(inputs=vgg_model.input, outputs=vgg_output)
for layer in vgg_model.layers:
    layer.trainable = False

# Feature extraction with ResNet50
resnet_model =  ResNet50(weights='/kaggle/input/resnet50/keras/default/1/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5',
                      include_top=False, 
                      input_shape=(224, 224, 3))

resnet_output = GlobalAveragePooling2D()(resnet_model.output)
resnet_feature_extractor = Model(inputs=resnet_model.input, outputs=resnet_output)
for layer in resnet_model.layers:
    layer.trainable = False

# Extract features from the training, validation, and test sets
X_train_vgg = vgg_feature_extractor.predict(X_train)
X_val_vgg = vgg_feature_extractor.predict(X_val)
X_test_vgg = vgg_feature_extractor.predict(test_images)

X_train_resnet = resnet_feature_extractor.predict(X_train)
X_val_resnet = resnet_feature_extractor.predict(X_val)
X_test_resnet = resnet_feature_extractor.predict(test_images)

# Flatten the features for concatenation
X_train_vgg = X_train_vgg.reshape((X_train_vgg.shape[0], -1))
X_val_vgg = X_val_vgg.reshape((X_val_vgg.shape[0], -1))
X_test_vgg = X_test_vgg.reshape((X_test_vgg.shape[0], -1))

X_train_resnet = X_train_resnet.reshape((X_train_resnet.shape[0], -1))
X_val_resnet = X_val_resnet.reshape((X_val_resnet.shape[0], -1))
X_test_resnet = X_test_resnet.reshape((X_test_resnet.shape[0], -1))

# Concatenate VGG16 and ResNet50 features
X_train_features = np.hstack((X_train_vgg, X_train_resnet))
X_val_features = np.hstack((X_val_vgg, X_val_resnet))
X_test_features = np.hstack((X_test_vgg, X_test_resnet))

# Standardize the features
scaler = StandardScaler()
X_train_features = scaler.fit_transform(X_train_features)
X_val_features = scaler.transform(X_val_features)
X_test_features = scaler.transform(X_test_features)

# Train base classifiers
lr = LogisticRegression(max_iter=500)
rf = RandomForestClassifier(n_estimators=100)
svm = SVC(probability=True)

lr.fit(X_train_features, y_train)
rf.fit(X_train_features, y_train)
svm.fit(X_train_features, y_train)

# Get base model predictions
lr_train_pred = lr.predict_proba(X_train_features)
rf_train_pred = rf.predict_proba(X_train_features)
svm_train_pred = svm.predict_proba(X_train_features)

# Stack base model predictions
meta_X_train = np.hstack((lr_train_pred, rf_train_pred, svm_train_pred))

# Validation set stacking
lr_val_pred = lr.predict_proba(X_val_features)
rf_val_pred = rf.predict_proba(X_val_features)
svm_val_pred = svm.predict_proba(X_val_features)
meta_X_val = np.hstack((lr_val_pred, rf_val_pred, svm_val_pred))

# Convert one-hot encoded labels back to single-column format for XGBoost
y_train_single = y_train  # No need to change, already single-class
y_val_single = y_val  # Already single-class
y_test_single = test_labels  # Use this for evaluation later

# XGBoost as meta-learner
meta_learner = xgb.XGBClassifier(n_estimators=500, learning_rate=0.001, max_depth=4, eval_metric=['logloss', 'error'])
eval_set = [(meta_X_train, y_train_single), (meta_X_val, y_val_single)]
meta_learner.fit(meta_X_train, y_train_single, eval_set=eval_set, verbose=True)

# Test set stacking
lr_test_pred = lr.predict_proba(X_test_features)
rf_test_pred = rf.predict_proba(X_test_features)
svm_test_pred = svm.predict_proba(X_test_features)
meta_X_test = np.hstack((lr_test_pred, rf_test_pred, svm_test_pred))

# Evaluate meta-learner
y_pred = meta_learner.predict(meta_X_test)

# Metrics
test_accuracy = accuracy_score(y_test_single, y_pred)
test_f1 = f1_score(y_test_single, y_pred, average='macro')
test_precision = precision_score(y_test_single, y_pred, average='macro')
test_recall = recall_score(y_test_single, y_pred, average='macro')
test_roc_auc = roc_auc_score(y_test_single, y_pred)

print(f'Test Accuracy: {test_accuracy * 100:.5f}%')
print(f'Test F1 Score: {test_f1:.5f}')
print(f'Test Precision: {test_precision:.5f}')
print(f'Test Recall: {test_recall:.5f}')
print(f'Test ROC AUC: {test_roc_auc:.5f}')
# Out:
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 8s 146ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 9s 155ms/step
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 146ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 110ms/step
# [0]	validation_0-logloss:0.67488	validation_0-error:0.40734	validation_1-logloss:0.67141	validation_1-error:0.39792
# [1]	validation_0-logloss:0.67389	validation_0-error:0.40734	validation_1-logloss:0.67043	validation_1-error:0.39792
# [2]	validation_0-logloss:0.67290	validation_0-error:0.40734	validation_1-logloss:0.66945	validation_1-error:0.39792
# [3]	validation_0-logloss:0.67192	validation_0-error:0.40734	validation_1-logloss:0.66848	validation_1-error:0.39792
# [4]	validation_0-logloss:0.67093	validation_0-error:0.40734	validation_1-logloss:0.66751	validation_1-error:0.39792
# [5]	validation_0-logloss:0.66995	validation_0-error:0.40734	validation_1-logloss:0.66654	validation_1-error:0.39792
# [6]	validation_0-logloss:0.66897	validation_0-error:0.40734	validation_1-logloss:0.66557	validation_1-error:0.39792
# [7]	validation_0-logloss:0.66799	validation_0-error:0.40734	validation_1-logloss:0.66460	validation_1-error:0.39792
# [8]	validation_0-logloss:0.66701	validation_0-error:0.40734	validation_1-logloss:0.66364	validation_1-error:0.39792
# [9]	validation_0-logloss:0.66604	validation_0-error:0.40734	validation_1-logloss:0.66268	validation_1-error:0.39792
# [10]	validation_0-logloss:0.66507	validation_0-error:0.40734	validation_1-logloss:0.66172	validation_1-error:0.39792
# [11]	validation_0-logloss:0.66410	validation_0-error:0.40734	validation_1-logloss:0.66076	validation_1-error:0.39792
# [12]	validation_0-logloss:0.66313	validation_0-error:0.40734	validation_1-logloss:0.65980	validation_1-error:0.39792
# [13]	validation_0-logloss:0.66216	validation_0-error:0.40734	validation_1-logloss:0.65885	validation_1-error:0.39792
# [14]	validation_0-logloss:0.66120	validation_0-error:0.40734	validation_1-logloss:0.65790	validation_1-error:0.39792
# [15]	validation_0-logloss:0.66023	validation_0-error:0.40734	validation_1-logloss:0.65695	validation_1-error:0.39792
# [16]	validation_0-logloss:0.65927	validation_0-error:0.40734	validation_1-logloss:0.65600	validation_1-error:0.39792
# [17]	validation_0-logloss:0.65831	validation_0-error:0.40734	validation_1-logloss:0.65505	validation_1-error:0.39792
# [18]	validation_0-logloss:0.65736	validation_0-error:0.40734	validation_1-logloss:0.65411	validation_1-error:0.39792
# [19]	validation_0-logloss:0.65640	validation_0-error:0.40734	validation_1-logloss:0.65317	validation_1-error:0.39792
# [20]	validation_0-logloss:0.65545	validation_0-error:0.40734	validation_1-logloss:0.65223	validation_1-error:0.39792
# [21]	validation_0-logloss:0.65450	validation_0-error:0.40734	validation_1-logloss:0.65129	validation_1-error:0.39792
# [22]	validation_0-logloss:0.65355	validation_0-error:0.40734	validation_1-logloss:0.65035	validation_1-error:0.39792
# [23]	validation_0-logloss:0.65261	validation_0-error:0.40734	validation_1-logloss:0.64942	validation_1-error:0.39792
# [24]	validation_0-logloss:0.65166	validation_0-error:0.40734	validation_1-logloss:0.64849	validation_1-error:0.39792
# [25]	validation_0-logloss:0.65072	validation_0-error:0.40734	validation_1-logloss:0.64756	validation_1-error:0.39792
# [26]	validation_0-logloss:0.64978	validation_0-error:0.40734	validation_1-logloss:0.64663	validation_1-error:0.39792
# [27]	validation_0-logloss:0.64884	validation_0-error:0.40734	validation_1-logloss:0.64570	validation_1-error:0.39792
# [28]	validation_0-logloss:0.64790	validation_0-error:0.40734	validation_1-logloss:0.64478	validation_1-error:0.39792
# [29]	validation_0-logloss:0.64697	validation_0-error:0.40734	validation_1-logloss:0.64385	validation_1-error:0.39792
# [30]	validation_0-logloss:0.64603	validation_0-error:0.40734	validation_1-logloss:0.64293	validation_1-error:0.39792
# [31]	validation_0-logloss:0.64510	validation_0-error:0.40734	validation_1-logloss:0.64201	validation_1-error:0.39792
# [32]	validation_0-logloss:0.64417	validation_0-error:0.40734	validation_1-logloss:0.64110	validation_1-error:0.39792
# [33]	validation_0-logloss:0.64325	validation_0-error:0.40734	validation_1-logloss:0.64018	validation_1-error:0.39792
# [34]	validation_0-logloss:0.64232	validation_0-error:0.40734	validation_1-logloss:0.63927	validation_1-error:0.39792
# [35]	validation_0-logloss:0.64140	validation_0-error:0.40734	validation_1-logloss:0.63836	validation_1-error:0.39792
# [36]	validation_0-logloss:0.64048	validation_0-error:0.40734	validation_1-logloss:0.63745	validation_1-error:0.39792
# [37]	validation_0-logloss:0.63956	validation_0-error:0.40734	validation_1-logloss:0.63654	validation_1-error:0.39792
# [38]	validation_0-logloss:0.63864	validation_0-error:0.40734	validation_1-logloss:0.63563	validation_1-error:0.39792
# [39]	validation_0-logloss:0.63772	validation_0-error:0.40734	validation_1-logloss:0.63473	validation_1-error:0.39792
# [40]	validation_0-logloss:0.63681	validation_0-error:0.40734	validation_1-logloss:0.63383	validation_1-error:0.39792
# [41]	validation_0-logloss:0.63590	validation_0-error:0.40734	validation_1-logloss:0.63293	validation_1-error:0.39792
# [42]	validation_0-logloss:0.63499	validation_0-error:0.40734	validation_1-logloss:0.63203	validation_1-error:0.39792
# [43]	validation_0-logloss:0.63408	validation_0-error:0.40734	validation_1-logloss:0.63113	validation_1-error:0.39792
# [44]	validation_0-logloss:0.63317	validation_0-error:0.40734	validation_1-logloss:0.63024	validation_1-error:0.39792
# [45]	validation_0-logloss:0.63226	validation_0-error:0.40734	validation_1-logloss:0.62934	validation_1-error:0.39792
# [46]	validation_0-logloss:0.63136	validation_0-error:0.40734	validation_1-logloss:0.62845	validation_1-error:0.39792
# [47]	validation_0-logloss:0.63046	validation_0-error:0.40734	validation_1-logloss:0.62756	validation_1-error:0.39792
# [48]	validation_0-logloss:0.62956	validation_0-error:0.40734	validation_1-logloss:0.62667	validation_1-error:0.39792
# [49]	validation_0-logloss:0.62866	validation_0-error:0.40734	validation_1-logloss:0.62579	validation_1-error:0.39792
# [50]	validation_0-logloss:0.62777	validation_0-error:0.40734	validation_1-logloss:0.62490	validation_1-error:0.39792
# [51]	validation_0-logloss:0.62687	validation_0-error:0.40734	validation_1-logloss:0.62402	validation_1-error:0.39792
# [52]	validation_0-logloss:0.62598	validation_0-error:0.40734	validation_1-logloss:0.62314	validation_1-error:0.39792
# [53]	validation_0-logloss:0.62509	validation_0-error:0.40734	validation_1-logloss:0.62226	validation_1-error:0.39792
# [54]	validation_0-logloss:0.62420	validation_0-error:0.40734	validation_1-logloss:0.62138	validation_1-error:0.39792
# [55]	validation_0-logloss:0.62331	validation_0-error:0.40734	validation_1-logloss:0.62051	validation_1-error:0.39792
# [56]	validation_0-logloss:0.62243	validation_0-error:0.40734	validation_1-logloss:0.61964	validation_1-error:0.39792
# [57]	validation_0-logloss:0.62155	validation_0-error:0.40734	validation_1-logloss:0.61876	validation_1-error:0.39792
# [58]	validation_0-logloss:0.62066	validation_0-error:0.40734	validation_1-logloss:0.61789	validation_1-error:0.39792
# [59]	validation_0-logloss:0.61978	validation_0-error:0.40734	validation_1-logloss:0.61703	validation_1-error:0.39792
# [60]	validation_0-logloss:0.61891	validation_0-error:0.40734	validation_1-logloss:0.61616	validation_1-error:0.39792
# [61]	validation_0-logloss:0.61803	validation_0-error:0.40734	validation_1-logloss:0.61529	validation_1-error:0.39792
# [62]	validation_0-logloss:0.61715	validation_0-error:0.40734	validation_1-logloss:0.61443	validation_1-error:0.39792
# [63]	validation_0-logloss:0.61628	validation_0-error:0.40734	validation_1-logloss:0.61357	validation_1-error:0.39792
# [64]	validation_0-logloss:0.61541	validation_0-error:0.40734	validation_1-logloss:0.61271	validation_1-error:0.39792
# [65]	validation_0-logloss:0.61454	validation_0-error:0.40734	validation_1-logloss:0.61185	validation_1-error:0.39792
# [66]	validation_0-logloss:0.61367	validation_0-error:0.40734	validation_1-logloss:0.61099	validation_1-error:0.39792
# [67]	validation_0-logloss:0.61281	validation_0-error:0.40734	validation_1-logloss:0.61014	validation_1-error:0.39792
# [68]	validation_0-logloss:0.61194	validation_0-error:0.40734	validation_1-logloss:0.60929	validation_1-error:0.39792
# [69]	validation_0-logloss:0.61108	validation_0-error:0.40734	validation_1-logloss:0.60843	validation_1-error:0.39792
# [70]	validation_0-logloss:0.61022	validation_0-error:0.40734	validation_1-logloss:0.60758	validation_1-error:0.39792
# [71]	validation_0-logloss:0.60936	validation_0-error:0.40734	validation_1-logloss:0.60674	validation_1-error:0.39792
# [72]	validation_0-logloss:0.60850	validation_0-error:0.40734	validation_1-logloss:0.60589	validation_1-error:0.39792
# [73]	validation_0-logloss:0.60764	validation_0-error:0.40734	validation_1-logloss:0.60504	validation_1-error:0.39792
# [74]	validation_0-logloss:0.60679	validation_0-error:0.40734	validation_1-logloss:0.60420	validation_1-error:0.39792
# [75]	validation_0-logloss:0.60594	validation_0-error:0.40734	validation_1-logloss:0.60336	validation_1-error:0.39792
# [76]	validation_0-logloss:0.60509	validation_0-error:0.40734	validation_1-logloss:0.60252	validation_1-error:0.39792
# [77]	validation_0-logloss:0.60424	validation_0-error:0.40734	validation_1-logloss:0.60168	validation_1-error:0.39792
# [78]	validation_0-logloss:0.60339	validation_0-error:0.40734	validation_1-logloss:0.60085	validation_1-error:0.39792
# [79]	validation_0-logloss:0.60254	validation_0-error:0.40734	validation_1-logloss:0.60001	validation_1-error:0.39792
# [80]	validation_0-logloss:0.60170	validation_0-error:0.40734	validation_1-logloss:0.59918	validation_1-error:0.39792
# [81]	validation_0-logloss:0.60086	validation_0-error:0.40734	validation_1-logloss:0.59835	validation_1-error:0.39792
# [82]	validation_0-logloss:0.60001	validation_0-error:0.40734	validation_1-logloss:0.59752	validation_1-error:0.39792
# [83]	validation_0-logloss:0.59917	validation_0-error:0.40734	validation_1-logloss:0.59669	validation_1-error:0.39792
# [84]	validation_0-logloss:0.59834	validation_0-error:0.40734	validation_1-logloss:0.59586	validation_1-error:0.39792
# [85]	validation_0-logloss:0.59750	validation_0-error:0.40734	validation_1-logloss:0.59503	validation_1-error:0.39792
# [86]	validation_0-logloss:0.59667	validation_0-error:0.40734	validation_1-logloss:0.59421	validation_1-error:0.39792
# [87]	validation_0-logloss:0.59583	validation_0-error:0.40734	validation_1-logloss:0.59339	validation_1-error:0.39792
# [88]	validation_0-logloss:0.59500	validation_0-error:0.40734	validation_1-logloss:0.59257	validation_1-error:0.39792
# [89]	validation_0-logloss:0.59417	validation_0-error:0.40734	validation_1-logloss:0.59175	validation_1-error:0.39792
# [90]	validation_0-logloss:0.59334	validation_0-error:0.40734	validation_1-logloss:0.59093	validation_1-error:0.39792
# [91]	validation_0-logloss:0.59252	validation_0-error:0.40734	validation_1-logloss:0.59012	validation_1-error:0.39792
# [92]	validation_0-logloss:0.59169	validation_0-error:0.40734	validation_1-logloss:0.58930	validation_1-error:0.39792
# [93]	validation_0-logloss:0.59087	validation_0-error:0.40734	validation_1-logloss:0.58849	validation_1-error:0.39792
# [94]	validation_0-logloss:0.59005	validation_0-error:0.40734	validation_1-logloss:0.58768	validation_1-error:0.39792
# [95]	validation_0-logloss:0.58922	validation_0-error:0.40734	validation_1-logloss:0.58687	validation_1-error:0.39792
# [96]	validation_0-logloss:0.58841	validation_0-error:0.40734	validation_1-logloss:0.58606	validation_1-error:0.39792
# [97]	validation_0-logloss:0.58759	validation_0-error:0.40734	validation_1-logloss:0.58525	validation_1-error:0.39792
# [98]	validation_0-logloss:0.58677	validation_0-error:0.40734	validation_1-logloss:0.58445	validation_1-error:0.39792
# [99]	validation_0-logloss:0.58596	validation_0-error:0.40734	validation_1-logloss:0.58365	validation_1-error:0.39792
# [100]	validation_0-logloss:0.58515	validation_0-error:0.40734	validation_1-logloss:0.58284	validation_1-error:0.39792
# [101]	validation_0-logloss:0.58434	validation_0-error:0.40734	validation_1-logloss:0.58204	validation_1-error:0.39792
# [102]	validation_0-logloss:0.58353	validation_0-error:0.40734	validation_1-logloss:0.58124	validation_1-error:0.39792
# [103]	validation_0-logloss:0.58272	validation_0-error:0.40734	validation_1-logloss:0.58045	validation_1-error:0.39792
# [104]	validation_0-logloss:0.58191	validation_0-error:0.40734	validation_1-logloss:0.57965	validation_1-error:0.39792
# [105]	validation_0-logloss:0.58111	validation_0-error:0.40734	validation_1-logloss:0.57886	validation_1-error:0.39792
# [106]	validation_0-logloss:0.58030	validation_0-error:0.40734	validation_1-logloss:0.57806	validation_1-error:0.39792
# [107]	validation_0-logloss:0.57950	validation_0-error:0.40734	validation_1-logloss:0.57727	validation_1-error:0.39792
# [108]	validation_0-logloss:0.57870	validation_0-error:0.40734	validation_1-logloss:0.57648	validation_1-error:0.39792
# [109]	validation_0-logloss:0.57790	validation_0-error:0.40734	validation_1-logloss:0.57570	validation_1-error:0.39792
# [110]	validation_0-logloss:0.57710	validation_0-error:0.40734	validation_1-logloss:0.57491	validation_1-error:0.39792
# [111]	validation_0-logloss:0.57631	validation_0-error:0.40734	validation_1-logloss:0.57412	validation_1-error:0.39792
# [112]	validation_0-logloss:0.57551	validation_0-error:0.40734	validation_1-logloss:0.57334	validation_1-error:0.39792
# [113]	validation_0-logloss:0.57472	validation_0-error:0.40734	validation_1-logloss:0.57256	validation_1-error:0.39792
# [114]	validation_0-logloss:0.57393	validation_0-error:0.40734	validation_1-logloss:0.57178	validation_1-error:0.39792
# [115]	validation_0-logloss:0.57314	validation_0-error:0.40734	validation_1-logloss:0.57100	validation_1-error:0.39792
# [116]	validation_0-logloss:0.57235	validation_0-error:0.40734	validation_1-logloss:0.57022	validation_1-error:0.39792
# [117]	validation_0-logloss:0.57156	validation_0-error:0.40734	validation_1-logloss:0.56944	validation_1-error:0.39792
# [118]	validation_0-logloss:0.57078	validation_0-error:0.40734	validation_1-logloss:0.56867	validation_1-error:0.39792
# [119]	validation_0-logloss:0.56999	validation_0-error:0.40734	validation_1-logloss:0.56789	validation_1-error:0.39792
# [120]	validation_0-logloss:0.56921	validation_0-error:0.40734	validation_1-logloss:0.56712	validation_1-error:0.39792
# [121]	validation_0-logloss:0.56843	validation_0-error:0.40734	validation_1-logloss:0.56635	validation_1-error:0.39792
# [122]	validation_0-logloss:0.56765	validation_0-error:0.40734	validation_1-logloss:0.56558	validation_1-error:0.39792
# [123]	validation_0-logloss:0.56687	validation_0-error:0.40734	validation_1-logloss:0.56481	validation_1-error:0.39792
# [124]	validation_0-logloss:0.56610	validation_0-error:0.40734	validation_1-logloss:0.56405	validation_1-error:0.39792
# [125]	validation_0-logloss:0.56532	validation_0-error:0.40734	validation_1-logloss:0.56328	validation_1-error:0.39792
# [126]	validation_0-logloss:0.56455	validation_0-error:0.40734	validation_1-logloss:0.56252	validation_1-error:0.39792
# [127]	validation_0-logloss:0.56377	validation_0-error:0.40734	validation_1-logloss:0.56176	validation_1-error:0.39792
# [128]	validation_0-logloss:0.56300	validation_0-error:0.40734	validation_1-logloss:0.56100	validation_1-error:0.39792
# [129]	validation_0-logloss:0.56223	validation_0-error:0.40734	validation_1-logloss:0.56024	validation_1-error:0.39792
# [130]	validation_0-logloss:0.56147	validation_0-error:0.40734	validation_1-logloss:0.55948	validation_1-error:0.39792
# [131]	validation_0-logloss:0.56070	validation_0-error:0.40734	validation_1-logloss:0.55872	validation_1-error:0.39792
# [132]	validation_0-logloss:0.55993	validation_0-error:0.40734	validation_1-logloss:0.55797	validation_1-error:0.39792
# [133]	validation_0-logloss:0.55917	validation_0-error:0.40734	validation_1-logloss:0.55721	validation_1-error:0.39792
# [134]	validation_0-logloss:0.55841	validation_0-error:0.40734	validation_1-logloss:0.55646	validation_1-error:0.39792
# [135]	validation_0-logloss:0.55765	validation_0-error:0.40734	validation_1-logloss:0.55571	validation_1-error:0.39792
# [136]	validation_0-logloss:0.55689	validation_0-error:0.40734	validation_1-logloss:0.55496	validation_1-error:0.39792
# [137]	validation_0-logloss:0.55613	validation_0-error:0.40734	validation_1-logloss:0.55421	validation_1-error:0.39792
# [138]	validation_0-logloss:0.55537	validation_0-error:0.40734	validation_1-logloss:0.55347	validation_1-error:0.39792
# [139]	validation_0-logloss:0.55462	validation_0-error:0.40734	validation_1-logloss:0.55272	validation_1-error:0.39792
# [140]	validation_0-logloss:0.55386	validation_0-error:0.40734	validation_1-logloss:0.55198	validation_1-error:0.39792
# [141]	validation_0-logloss:0.55311	validation_0-error:0.40734	validation_1-logloss:0.55123	validation_1-error:0.39792
# [142]	validation_0-logloss:0.55236	validation_0-error:0.40734	validation_1-logloss:0.55049	validation_1-error:0.39792
# [143]	validation_0-logloss:0.55161	validation_0-error:0.40734	validation_1-logloss:0.54975	validation_1-error:0.39792
# [144]	validation_0-logloss:0.55086	validation_0-error:0.40734	validation_1-logloss:0.54901	validation_1-error:0.39792
# [145]	validation_0-logloss:0.55011	validation_0-error:0.40734	validation_1-logloss:0.54828	validation_1-error:0.39792
# [146]	validation_0-logloss:0.54937	validation_0-error:0.40734	validation_1-logloss:0.54754	validation_1-error:0.39792
# [147]	validation_0-logloss:0.54862	validation_0-error:0.40734	validation_1-logloss:0.54681	validation_1-error:0.39792
# [148]	validation_0-logloss:0.54788	validation_0-error:0.40734	validation_1-logloss:0.54607	validation_1-error:0.39792
# [149]	validation_0-logloss:0.54714	validation_0-error:0.40734	validation_1-logloss:0.54534	validation_1-error:0.39792
# [150]	validation_0-logloss:0.54640	validation_0-error:0.40734	validation_1-logloss:0.54461	validation_1-error:0.39792
# [151]	validation_0-logloss:0.54566	validation_0-error:0.40734	validation_1-logloss:0.54388	validation_1-error:0.39792
# [152]	validation_0-logloss:0.54492	validation_0-error:0.40734	validation_1-logloss:0.54315	validation_1-error:0.39792
# [153]	validation_0-logloss:0.54418	validation_0-error:0.40734	validation_1-logloss:0.54243	validation_1-error:0.39792
# [154]	validation_0-logloss:0.54345	validation_0-error:0.40734	validation_1-logloss:0.54170	validation_1-error:0.39792
# [155]	validation_0-logloss:0.54271	validation_0-error:0.40734	validation_1-logloss:0.54098	validation_1-error:0.39792
# [156]	validation_0-logloss:0.54198	validation_0-error:0.40734	validation_1-logloss:0.54025	validation_1-error:0.39792
# [157]	validation_0-logloss:0.54125	validation_0-error:0.40734	validation_1-logloss:0.53953	validation_1-error:0.39792
# [158]	validation_0-logloss:0.54052	validation_0-error:0.40734	validation_1-logloss:0.53881	validation_1-error:0.39792
# [159]	validation_0-logloss:0.53979	validation_0-error:0.40734	validation_1-logloss:0.53809	validation_1-error:0.39792
# [160]	validation_0-logloss:0.53906	validation_0-error:0.40734	validation_1-logloss:0.53738	validation_1-error:0.39792
# [161]	validation_0-logloss:0.53834	validation_0-error:0.40734	validation_1-logloss:0.53666	validation_1-error:0.39792
# [162]	validation_0-logloss:0.53761	validation_0-error:0.40734	validation_1-logloss:0.53595	validation_1-error:0.39792
# [163]	validation_0-logloss:0.53689	validation_0-error:0.40734	validation_1-logloss:0.53523	validation_1-error:0.39792
# [164]	validation_0-logloss:0.53617	validation_0-error:0.40734	validation_1-logloss:0.53452	validation_1-error:0.39792
# [165]	validation_0-logloss:0.53545	validation_0-error:0.40734	validation_1-logloss:0.53381	validation_1-error:0.39792
# [166]	validation_0-logloss:0.53473	validation_0-error:0.40734	validation_1-logloss:0.53310	validation_1-error:0.39792
# [167]	validation_0-logloss:0.53401	validation_0-error:0.40734	validation_1-logloss:0.53239	validation_1-error:0.39792
# [168]	validation_0-logloss:0.53329	validation_0-error:0.40734	validation_1-logloss:0.53168	validation_1-error:0.39792
# [169]	validation_0-logloss:0.53258	validation_0-error:0.00000	validation_1-logloss:0.53098	validation_1-error:0.00346
# [170]	validation_0-logloss:0.53186	validation_0-error:0.00000	validation_1-logloss:0.53027	validation_1-error:0.00346
# [171]	validation_0-logloss:0.53115	validation_0-error:0.00000	validation_1-logloss:0.52957	validation_1-error:0.00346
# [172]	validation_0-logloss:0.53044	validation_0-error:0.00000	validation_1-logloss:0.52887	validation_1-error:0.00346
# [173]	validation_0-logloss:0.52973	validation_0-error:0.00000	validation_1-logloss:0.52817	validation_1-error:0.00346
# [174]	validation_0-logloss:0.52902	validation_0-error:0.00000	validation_1-logloss:0.52747	validation_1-error:0.00346
# [175]	validation_0-logloss:0.52831	validation_0-error:0.00000	validation_1-logloss:0.52677	validation_1-error:0.00346
# [176]	validation_0-logloss:0.52760	validation_0-error:0.00000	validation_1-logloss:0.52607	validation_1-error:0.00346
# [177]	validation_0-logloss:0.52690	validation_0-error:0.00000	validation_1-logloss:0.52538	validation_1-error:0.00346
# [178]	validation_0-logloss:0.52619	validation_0-error:0.00000	validation_1-logloss:0.52468	validation_1-error:0.00346
# [179]	validation_0-logloss:0.52549	validation_0-error:0.00000	validation_1-logloss:0.52399	validation_1-error:0.00346
# [180]	validation_0-logloss:0.52479	validation_0-error:0.00000	validation_1-logloss:0.52329	validation_1-error:0.00346
# [181]	validation_0-logloss:0.52409	validation_0-error:0.00000	validation_1-logloss:0.52260	validation_1-error:0.00346
# [182]	validation_0-logloss:0.52339	validation_0-error:0.00000	validation_1-logloss:0.52191	validation_1-error:0.00346
# [183]	validation_0-logloss:0.52269	validation_0-error:0.00000	validation_1-logloss:0.52123	validation_1-error:0.00346
# [184]	validation_0-logloss:0.52199	validation_0-error:0.00000	validation_1-logloss:0.52054	validation_1-error:0.00346
# [185]	validation_0-logloss:0.52130	validation_0-error:0.00000	validation_1-logloss:0.51985	validation_1-error:0.00346
# [186]	validation_0-logloss:0.52060	validation_0-error:0.00000	validation_1-logloss:0.51917	validation_1-error:0.00346
# [187]	validation_0-logloss:0.51991	validation_0-error:0.00000	validation_1-logloss:0.51848	validation_1-error:0.00346
# [188]	validation_0-logloss:0.51922	validation_0-error:0.00000	validation_1-logloss:0.51780	validation_1-error:0.00346
# [189]	validation_0-logloss:0.51853	validation_0-error:0.00000	validation_1-logloss:0.51712	validation_1-error:0.00346
# [190]	validation_0-logloss:0.51784	validation_0-error:0.00000	validation_1-logloss:0.51644	validation_1-error:0.00346
# [191]	validation_0-logloss:0.51715	validation_0-error:0.00000	validation_1-logloss:0.51576	validation_1-error:0.00346
# [192]	validation_0-logloss:0.51646	validation_0-error:0.00000	validation_1-logloss:0.51508	validation_1-error:0.00346
# [193]	validation_0-logloss:0.51578	validation_0-error:0.00000	validation_1-logloss:0.51441	validation_1-error:0.00346
# [194]	validation_0-logloss:0.51509	validation_0-error:0.00000	validation_1-logloss:0.51373	validation_1-error:0.00346
# [195]	validation_0-logloss:0.51441	validation_0-error:0.00000	validation_1-logloss:0.51306	validation_1-error:0.00346
# [196]	validation_0-logloss:0.51373	validation_0-error:0.00000	validation_1-logloss:0.51238	validation_1-error:0.00346
# [197]	validation_0-logloss:0.51305	validation_0-error:0.00000	validation_1-logloss:0.51171	validation_1-error:0.00346
# [198]	validation_0-logloss:0.51237	validation_0-error:0.00000	validation_1-logloss:0.51104	validation_1-error:0.00346
# [199]	validation_0-logloss:0.51169	validation_0-error:0.00000	validation_1-logloss:0.51037	validation_1-error:0.00346
# [200]	validation_0-logloss:0.51101	validation_0-error:0.00000	validation_1-logloss:0.50970	validation_1-error:0.00346
# [201]	validation_0-logloss:0.51033	validation_0-error:0.00000	validation_1-logloss:0.50904	validation_1-error:0.00346
# [202]	validation_0-logloss:0.50966	validation_0-error:0.00000	validation_1-logloss:0.50837	validation_1-error:0.00346
# [203]	validation_0-logloss:0.50898	validation_0-error:0.00000	validation_1-logloss:0.50771	validation_1-error:0.00346
# [204]	validation_0-logloss:0.50831	validation_0-error:0.00000	validation_1-logloss:0.50704	validation_1-error:0.00346
# [205]	validation_0-logloss:0.50764	validation_0-error:0.00000	validation_1-logloss:0.50638	validation_1-error:0.00346
# [206]	validation_0-logloss:0.50697	validation_0-error:0.00000	validation_1-logloss:0.50572	validation_1-error:0.00346
# [207]	validation_0-logloss:0.50630	validation_0-error:0.00000	validation_1-logloss:0.50506	validation_1-error:0.00346
# [208]	validation_0-logloss:0.50563	validation_0-error:0.00000	validation_1-logloss:0.50440	validation_1-error:0.00346
# [209]	validation_0-logloss:0.50497	validation_0-error:0.00000	validation_1-logloss:0.50374	validation_1-error:0.00346
# [210]	validation_0-logloss:0.50430	validation_0-error:0.00000	validation_1-logloss:0.50309	validation_1-error:0.00346
# [211]	validation_0-logloss:0.50363	validation_0-error:0.00000	validation_1-logloss:0.50243	validation_1-error:0.00346
# [212]	validation_0-logloss:0.50297	validation_0-error:0.00000	validation_1-logloss:0.50178	validation_1-error:0.00346
# [213]	validation_0-logloss:0.50231	validation_0-error:0.00000	validation_1-logloss:0.50112	validation_1-error:0.00346
# [214]	validation_0-logloss:0.50165	validation_0-error:0.00000	validation_1-logloss:0.50047	validation_1-error:0.00346
# [215]	validation_0-logloss:0.50099	validation_0-error:0.00000	validation_1-logloss:0.49982	validation_1-error:0.00346
# [216]	validation_0-logloss:0.50033	validation_0-error:0.00000	validation_1-logloss:0.49917	validation_1-error:0.00346
# [217]	validation_0-logloss:0.49967	validation_0-error:0.00000	validation_1-logloss:0.49852	validation_1-error:0.00346
# [218]	validation_0-logloss:0.49901	validation_0-error:0.00000	validation_1-logloss:0.49787	validation_1-error:0.00346
# [219]	validation_0-logloss:0.49836	validation_0-error:0.00000	validation_1-logloss:0.49723	validation_1-error:0.00346
# [220]	validation_0-logloss:0.49770	validation_0-error:0.00000	validation_1-logloss:0.49658	validation_1-error:0.00346
# [221]	validation_0-logloss:0.49705	validation_0-error:0.00000	validation_1-logloss:0.49594	validation_1-error:0.00346
# [222]	validation_0-logloss:0.49640	validation_0-error:0.00000	validation_1-logloss:0.49529	validation_1-error:0.00346
# [223]	validation_0-logloss:0.49575	validation_0-error:0.00000	validation_1-logloss:0.49465	validation_1-error:0.00346
# [224]	validation_0-logloss:0.49510	validation_0-error:0.00000	validation_1-logloss:0.49401	validation_1-error:0.00346
# [225]	validation_0-logloss:0.49445	validation_0-error:0.00000	validation_1-logloss:0.49337	validation_1-error:0.00346
# [226]	validation_0-logloss:0.49380	validation_0-error:0.00000	validation_1-logloss:0.49273	validation_1-error:0.00346
# [227]	validation_0-logloss:0.49315	validation_0-error:0.00000	validation_1-logloss:0.49209	validation_1-error:0.00346
# [228]	validation_0-logloss:0.49251	validation_0-error:0.00000	validation_1-logloss:0.49146	validation_1-error:0.00346
# [229]	validation_0-logloss:0.49186	validation_0-error:0.00000	validation_1-logloss:0.49082	validation_1-error:0.00346
# [230]	validation_0-logloss:0.49122	validation_0-error:0.00000	validation_1-logloss:0.49019	validation_1-error:0.00346
# [231]	validation_0-logloss:0.49058	validation_0-error:0.00000	validation_1-logloss:0.48955	validation_1-error:0.00346
# [232]	validation_0-logloss:0.48994	validation_0-error:0.00000	validation_1-logloss:0.48892	validation_1-error:0.00346
# [233]	validation_0-logloss:0.48930	validation_0-error:0.00000	validation_1-logloss:0.48829	validation_1-error:0.00346
# [234]	validation_0-logloss:0.48866	validation_0-error:0.00000	validation_1-logloss:0.48766	validation_1-error:0.00346
# [235]	validation_0-logloss:0.48802	validation_0-error:0.00000	validation_1-logloss:0.48703	validation_1-error:0.00346
# [236]	validation_0-logloss:0.48738	validation_0-error:0.00000	validation_1-logloss:0.48640	validation_1-error:0.00346
# [237]	validation_0-logloss:0.48675	validation_0-error:0.00000	validation_1-logloss:0.48577	validation_1-error:0.00346
# [238]	validation_0-logloss:0.48611	validation_0-error:0.00000	validation_1-logloss:0.48515	validation_1-error:0.00346
# [239]	validation_0-logloss:0.48548	validation_0-error:0.00000	validation_1-logloss:0.48452	validation_1-error:0.00346
# [240]	validation_0-logloss:0.48485	validation_0-error:0.00000	validation_1-logloss:0.48390	validation_1-error:0.00346
# [241]	validation_0-logloss:0.48421	validation_0-error:0.00000	validation_1-logloss:0.48328	validation_1-error:0.00346
# [242]	validation_0-logloss:0.48358	validation_0-error:0.00000	validation_1-logloss:0.48266	validation_1-error:0.00346
# [243]	validation_0-logloss:0.48295	validation_0-error:0.00000	validation_1-logloss:0.48203	validation_1-error:0.00346
# [244]	validation_0-logloss:0.48233	validation_0-error:0.00000	validation_1-logloss:0.48142	validation_1-error:0.00346
# [245]	validation_0-logloss:0.48170	validation_0-error:0.00000	validation_1-logloss:0.48080	validation_1-error:0.00346
# [246]	validation_0-logloss:0.48107	validation_0-error:0.00000	validation_1-logloss:0.48018	validation_1-error:0.00346
# [247]	validation_0-logloss:0.48045	validation_0-error:0.00000	validation_1-logloss:0.47956	validation_1-error:0.00346
# [248]	validation_0-logloss:0.47982	validation_0-error:0.00000	validation_1-logloss:0.47895	validation_1-error:0.00346
# [249]	validation_0-logloss:0.47920	validation_0-error:0.00000	validation_1-logloss:0.47833	validation_1-error:0.00346
# [250]	validation_0-logloss:0.47858	validation_0-error:0.00000	validation_1-logloss:0.47772	validation_1-error:0.00346
# [251]	validation_0-logloss:0.47796	validation_0-error:0.00000	validation_1-logloss:0.47711	validation_1-error:0.00346
# [252]	validation_0-logloss:0.47734	validation_0-error:0.00000	validation_1-logloss:0.47650	validation_1-error:0.00346
# [253]	validation_0-logloss:0.47672	validation_0-error:0.00000	validation_1-logloss:0.47589	validation_1-error:0.00346
# [254]	validation_0-logloss:0.47610	validation_0-error:0.00000	validation_1-logloss:0.47528	validation_1-error:0.00346
# [255]	validation_0-logloss:0.47548	validation_0-error:0.00000	validation_1-logloss:0.47467	validation_1-error:0.00346
# [256]	validation_0-logloss:0.47487	validation_0-error:0.00000	validation_1-logloss:0.47406	validation_1-error:0.00346
# [257]	validation_0-logloss:0.47425	validation_0-error:0.00000	validation_1-logloss:0.47345	validation_1-error:0.00346
# [258]	validation_0-logloss:0.47364	validation_0-error:0.00000	validation_1-logloss:0.47285	validation_1-error:0.00346
# [259]	validation_0-logloss:0.47303	validation_0-error:0.00000	validation_1-logloss:0.47225	validation_1-error:0.00346
# [260]	validation_0-logloss:0.47241	validation_0-error:0.00000	validation_1-logloss:0.47164	validation_1-error:0.00346
# [261]	validation_0-logloss:0.47180	validation_0-error:0.00000	validation_1-logloss:0.47104	validation_1-error:0.00346
# [262]	validation_0-logloss:0.47119	validation_0-error:0.00000	validation_1-logloss:0.47044	validation_1-error:0.00346
# [263]	validation_0-logloss:0.47058	validation_0-error:0.00000	validation_1-logloss:0.46984	validation_1-error:0.00346
# [264]	validation_0-logloss:0.46998	validation_0-error:0.00000	validation_1-logloss:0.46924	validation_1-error:0.00346
# [265]	validation_0-logloss:0.46937	validation_0-error:0.00000	validation_1-logloss:0.46864	validation_1-error:0.00346
# [266]	validation_0-logloss:0.46876	validation_0-error:0.00000	validation_1-logloss:0.46804	validation_1-error:0.00346
# [267]	validation_0-logloss:0.46816	validation_0-error:0.00000	validation_1-logloss:0.46745	validation_1-error:0.00346
# [268]	validation_0-logloss:0.46756	validation_0-error:0.00000	validation_1-logloss:0.46685	validation_1-error:0.00346
# [269]	validation_0-logloss:0.46695	validation_0-error:0.00000	validation_1-logloss:0.46626	validation_1-error:0.00346
# [270]	validation_0-logloss:0.46635	validation_0-error:0.00000	validation_1-logloss:0.46567	validation_1-error:0.00346
# [271]	validation_0-logloss:0.46575	validation_0-error:0.00000	validation_1-logloss:0.46507	validation_1-error:0.00346
# [272]	validation_0-logloss:0.46515	validation_0-error:0.00000	validation_1-logloss:0.46448	validation_1-error:0.00346
# [273]	validation_0-logloss:0.46455	validation_0-error:0.00000	validation_1-logloss:0.46389	validation_1-error:0.00346
# [274]	validation_0-logloss:0.46396	validation_0-error:0.00000	validation_1-logloss:0.46330	validation_1-error:0.00346
# [275]	validation_0-logloss:0.46336	validation_0-error:0.00000	validation_1-logloss:0.46271	validation_1-error:0.00346
# [276]	validation_0-logloss:0.46276	validation_0-error:0.00000	validation_1-logloss:0.46213	validation_1-error:0.00346
# [277]	validation_0-logloss:0.46217	validation_0-error:0.00000	validation_1-logloss:0.46154	validation_1-error:0.00346
# [278]	validation_0-logloss:0.46157	validation_0-error:0.00000	validation_1-logloss:0.46096	validation_1-error:0.00346
# [279]	validation_0-logloss:0.46098	validation_0-error:0.00000	validation_1-logloss:0.46037	validation_1-error:0.00346
# [280]	validation_0-logloss:0.46039	validation_0-error:0.00000	validation_1-logloss:0.45979	validation_1-error:0.00346
# [281]	validation_0-logloss:0.45980	validation_0-error:0.00000	validation_1-logloss:0.45920	validation_1-error:0.00346
# [282]	validation_0-logloss:0.45921	validation_0-error:0.00000	validation_1-logloss:0.45862	validation_1-error:0.00346
# [283]	validation_0-logloss:0.45862	validation_0-error:0.00000	validation_1-logloss:0.45804	validation_1-error:0.00346
# [284]	validation_0-logloss:0.45803	validation_0-error:0.00000	validation_1-logloss:0.45746	validation_1-error:0.00346
# [285]	validation_0-logloss:0.45744	validation_0-error:0.00000	validation_1-logloss:0.45688	validation_1-error:0.00346
# [286]	validation_0-logloss:0.45686	validation_0-error:0.00000	validation_1-logloss:0.45631	validation_1-error:0.00346
# [287]	validation_0-logloss:0.45627	validation_0-error:0.00000	validation_1-logloss:0.45573	validation_1-error:0.00346
# [288]	validation_0-logloss:0.45569	validation_0-error:0.00000	validation_1-logloss:0.45515	validation_1-error:0.00346
# [289]	validation_0-logloss:0.45511	validation_0-error:0.00000	validation_1-logloss:0.45458	validation_1-error:0.00346
# [290]	validation_0-logloss:0.45452	validation_0-error:0.00000	validation_1-logloss:0.45401	validation_1-error:0.00346
# [291]	validation_0-logloss:0.45394	validation_0-error:0.00000	validation_1-logloss:0.45343	validation_1-error:0.00346
# [292]	validation_0-logloss:0.45336	validation_0-error:0.00000	validation_1-logloss:0.45286	validation_1-error:0.00346
# [293]	validation_0-logloss:0.45278	validation_0-error:0.00000	validation_1-logloss:0.45229	validation_1-error:0.00346
# [294]	validation_0-logloss:0.45220	validation_0-error:0.00000	validation_1-logloss:0.45172	validation_1-error:0.00346
# [295]	validation_0-logloss:0.45163	validation_0-error:0.00000	validation_1-logloss:0.45115	validation_1-error:0.00346
# [296]	validation_0-logloss:0.45105	validation_0-error:0.00000	validation_1-logloss:0.45058	validation_1-error:0.00346
# [297]	validation_0-logloss:0.45048	validation_0-error:0.00000	validation_1-logloss:0.45001	validation_1-error:0.00346
# [298]	validation_0-logloss:0.44990	validation_0-error:0.00000	validation_1-logloss:0.44945	validation_1-error:0.00346
# [299]	validation_0-logloss:0.44933	validation_0-error:0.00000	validation_1-logloss:0.44888	validation_1-error:0.00346
# [300]	validation_0-logloss:0.44875	validation_0-error:0.00000	validation_1-logloss:0.44832	validation_1-error:0.00346
# [301]	validation_0-logloss:0.44818	validation_0-error:0.00000	validation_1-logloss:0.44775	validation_1-error:0.00346
# [302]	validation_0-logloss:0.44761	validation_0-error:0.00000	validation_1-logloss:0.44719	validation_1-error:0.00346
# [303]	validation_0-logloss:0.44704	validation_0-error:0.00000	validation_1-logloss:0.44663	validation_1-error:0.00346
# [304]	validation_0-logloss:0.44647	validation_0-error:0.00000	validation_1-logloss:0.44607	validation_1-error:0.00346
# [305]	validation_0-logloss:0.44590	validation_0-error:0.00000	validation_1-logloss:0.44551	validation_1-error:0.00346
# [306]	validation_0-logloss:0.44534	validation_0-error:0.00000	validation_1-logloss:0.44495	validation_1-error:0.00346
# [307]	validation_0-logloss:0.44477	validation_0-error:0.00000	validation_1-logloss:0.44439	validation_1-error:0.00346
# [308]	validation_0-logloss:0.44420	validation_0-error:0.00000	validation_1-logloss:0.44383	validation_1-error:0.00346
# [309]	validation_0-logloss:0.44364	validation_0-error:0.00000	validation_1-logloss:0.44328	validation_1-error:0.00346
# [310]	validation_0-logloss:0.44308	validation_0-error:0.00000	validation_1-logloss:0.44272	validation_1-error:0.00346
# [311]	validation_0-logloss:0.44251	validation_0-error:0.00000	validation_1-logloss:0.44217	validation_1-error:0.00346
# [312]	validation_0-logloss:0.44195	validation_0-error:0.00000	validation_1-logloss:0.44161	validation_1-error:0.00346
# [313]	validation_0-logloss:0.44139	validation_0-error:0.00000	validation_1-logloss:0.44106	validation_1-error:0.00346
# [314]	validation_0-logloss:0.44083	validation_0-error:0.00000	validation_1-logloss:0.44051	validation_1-error:0.00346
# [315]	validation_0-logloss:0.44027	validation_0-error:0.00000	validation_1-logloss:0.43996	validation_1-error:0.00346
# [316]	validation_0-logloss:0.43971	validation_0-error:0.00000	validation_1-logloss:0.43941	validation_1-error:0.00346
# [317]	validation_0-logloss:0.43916	validation_0-error:0.00000	validation_1-logloss:0.43886	validation_1-error:0.00346
# [318]	validation_0-logloss:0.43860	validation_0-error:0.00000	validation_1-logloss:0.43831	validation_1-error:0.00346
# [319]	validation_0-logloss:0.43804	validation_0-error:0.00000	validation_1-logloss:0.43776	validation_1-error:0.00346
# [320]	validation_0-logloss:0.43749	validation_0-error:0.00000	validation_1-logloss:0.43721	validation_1-error:0.00346
# [321]	validation_0-logloss:0.43694	validation_0-error:0.00000	validation_1-logloss:0.43667	validation_1-error:0.00346
# [322]	validation_0-logloss:0.43638	validation_0-error:0.00000	validation_1-logloss:0.43612	validation_1-error:0.00346
# [323]	validation_0-logloss:0.43583	validation_0-error:0.00000	validation_1-logloss:0.43558	validation_1-error:0.00346
# [324]	validation_0-logloss:0.43528	validation_0-error:0.00000	validation_1-logloss:0.43504	validation_1-error:0.00346
# [325]	validation_0-logloss:0.43473	validation_0-error:0.00000	validation_1-logloss:0.43449	validation_1-error:0.00346
# [326]	validation_0-logloss:0.43418	validation_0-error:0.00000	validation_1-logloss:0.43395	validation_1-error:0.00346
# [327]	validation_0-logloss:0.43363	validation_0-error:0.00000	validation_1-logloss:0.43341	validation_1-error:0.00346
# [328]	validation_0-logloss:0.43308	validation_0-error:0.00000	validation_1-logloss:0.43287	validation_1-error:0.00346
# [329]	validation_0-logloss:0.43254	validation_0-error:0.00000	validation_1-logloss:0.43233	validation_1-error:0.00346
# [330]	validation_0-logloss:0.43199	validation_0-error:0.00000	validation_1-logloss:0.43180	validation_1-error:0.00346
# [331]	validation_0-logloss:0.43145	validation_0-error:0.00000	validation_1-logloss:0.43126	validation_1-error:0.00346
# [332]	validation_0-logloss:0.43090	validation_0-error:0.00000	validation_1-logloss:0.43072	validation_1-error:0.00346
# [333]	validation_0-logloss:0.43036	validation_0-error:0.00000	validation_1-logloss:0.43019	validation_1-error:0.00346
# [334]	validation_0-logloss:0.42982	validation_0-error:0.00000	validation_1-logloss:0.42965	validation_1-error:0.00346
# [335]	validation_0-logloss:0.42927	validation_0-error:0.00000	validation_1-logloss:0.42912	validation_1-error:0.00346
# [336]	validation_0-logloss:0.42873	validation_0-error:0.00000	validation_1-logloss:0.42859	validation_1-error:0.00346
# [337]	validation_0-logloss:0.42819	validation_0-error:0.00000	validation_1-logloss:0.42805	validation_1-error:0.00346
# [338]	validation_0-logloss:0.42765	validation_0-error:0.00000	validation_1-logloss:0.42752	validation_1-error:0.00346
# [339]	validation_0-logloss:0.42712	validation_0-error:0.00000	validation_1-logloss:0.42699	validation_1-error:0.00346
# [340]	validation_0-logloss:0.42658	validation_0-error:0.00000	validation_1-logloss:0.42646	validation_1-error:0.00346
# [341]	validation_0-logloss:0.42604	validation_0-error:0.00000	validation_1-logloss:0.42593	validation_1-error:0.00346
# [342]	validation_0-logloss:0.42551	validation_0-error:0.00000	validation_1-logloss:0.42541	validation_1-error:0.00346
# [343]	validation_0-logloss:0.42497	validation_0-error:0.00000	validation_1-logloss:0.42488	validation_1-error:0.00346
# [344]	validation_0-logloss:0.42444	validation_0-error:0.00000	validation_1-logloss:0.42435	validation_1-error:0.00346
# [345]	validation_0-logloss:0.42390	validation_0-error:0.00000	validation_1-logloss:0.42383	validation_1-error:0.00346
# [346]	validation_0-logloss:0.42337	validation_0-error:0.00000	validation_1-logloss:0.42330	validation_1-error:0.00346
# [347]	validation_0-logloss:0.42284	validation_0-error:0.00000	validation_1-logloss:0.42278	validation_1-error:0.00346
# [348]	validation_0-logloss:0.42231	validation_0-error:0.00000	validation_1-logloss:0.42226	validation_1-error:0.00346
# [349]	validation_0-logloss:0.42178	validation_0-error:0.00000	validation_1-logloss:0.42173	validation_1-error:0.00346
# [350]	validation_0-logloss:0.42125	validation_0-error:0.00000	validation_1-logloss:0.42121	validation_1-error:0.00346
# [351]	validation_0-logloss:0.42072	validation_0-error:0.00000	validation_1-logloss:0.42069	validation_1-error:0.00346
# [352]	validation_0-logloss:0.42020	validation_0-error:0.00000	validation_1-logloss:0.42017	validation_1-error:0.00346
# [353]	validation_0-logloss:0.41967	validation_0-error:0.00000	validation_1-logloss:0.41965	validation_1-error:0.00346
# [354]	validation_0-logloss:0.41914	validation_0-error:0.00000	validation_1-logloss:0.41914	validation_1-error:0.00346
# [355]	validation_0-logloss:0.41862	validation_0-error:0.00000	validation_1-logloss:0.41862	validation_1-error:0.00346
# [356]	validation_0-logloss:0.41810	validation_0-error:0.00000	validation_1-logloss:0.41810	validation_1-error:0.00346
# [357]	validation_0-logloss:0.41757	validation_0-error:0.00000	validation_1-logloss:0.41759	validation_1-error:0.00346
# [358]	validation_0-logloss:0.41705	validation_0-error:0.00000	validation_1-logloss:0.41707	validation_1-error:0.00346
# [359]	validation_0-logloss:0.41653	validation_0-error:0.00000	validation_1-logloss:0.41656	validation_1-error:0.00346
# [360]	validation_0-logloss:0.41601	validation_0-error:0.00000	validation_1-logloss:0.41605	validation_1-error:0.00346
# [361]	validation_0-logloss:0.41549	validation_0-error:0.00000	validation_1-logloss:0.41553	validation_1-error:0.00346
# [362]	validation_0-logloss:0.41497	validation_0-error:0.00000	validation_1-logloss:0.41502	validation_1-error:0.00346
# [363]	validation_0-logloss:0.41445	validation_0-error:0.00000	validation_1-logloss:0.41451	validation_1-error:0.00346
# [364]	validation_0-logloss:0.41393	validation_0-error:0.00000	validation_1-logloss:0.41400	validation_1-error:0.00346
# [365]	validation_0-logloss:0.41342	validation_0-error:0.00000	validation_1-logloss:0.41349	validation_1-error:0.00346
# [366]	validation_0-logloss:0.41290	validation_0-error:0.00000	validation_1-logloss:0.41298	validation_1-error:0.00346
# [367]	validation_0-logloss:0.41239	validation_0-error:0.00000	validation_1-logloss:0.41248	validation_1-error:0.00346
# [368]	validation_0-logloss:0.41187	validation_0-error:0.00000	validation_1-logloss:0.41197	validation_1-error:0.00346
# [369]	validation_0-logloss:0.41136	validation_0-error:0.00000	validation_1-logloss:0.41146	validation_1-error:0.00346
# [370]	validation_0-logloss:0.41084	validation_0-error:0.00000	validation_1-logloss:0.41096	validation_1-error:0.00346
# [371]	validation_0-logloss:0.41033	validation_0-error:0.00000	validation_1-logloss:0.41046	validation_1-error:0.00346
# [372]	validation_0-logloss:0.40982	validation_0-error:0.00000	validation_1-logloss:0.40995	validation_1-error:0.00346
# [373]	validation_0-logloss:0.40931	validation_0-error:0.00000	validation_1-logloss:0.40945	validation_1-error:0.00346
# [374]	validation_0-logloss:0.40880	validation_0-error:0.00000	validation_1-logloss:0.40895	validation_1-error:0.00346
# [375]	validation_0-logloss:0.40829	validation_0-error:0.00000	validation_1-logloss:0.40845	validation_1-error:0.00346
# [376]	validation_0-logloss:0.40779	validation_0-error:0.00000	validation_1-logloss:0.40795	validation_1-error:0.00346
# [377]	validation_0-logloss:0.40728	validation_0-error:0.00000	validation_1-logloss:0.40745	validation_1-error:0.00346
# [378]	validation_0-logloss:0.40677	validation_0-error:0.00000	validation_1-logloss:0.40695	validation_1-error:0.00346
# [379]	validation_0-logloss:0.40627	validation_0-error:0.00000	validation_1-logloss:0.40645	validation_1-error:0.00346
# [380]	validation_0-logloss:0.40576	validation_0-error:0.00000	validation_1-logloss:0.40595	validation_1-error:0.00346
# [381]	validation_0-logloss:0.40526	validation_0-error:0.00000	validation_1-logloss:0.40546	validation_1-error:0.00346
# [382]	validation_0-logloss:0.40475	validation_0-error:0.00000	validation_1-logloss:0.40496	validation_1-error:0.00346
# [383]	validation_0-logloss:0.40425	validation_0-error:0.00000	validation_1-logloss:0.40446	validation_1-error:0.00346
# [384]	validation_0-logloss:0.40375	validation_0-error:0.00000	validation_1-logloss:0.40397	validation_1-error:0.00346
# [385]	validation_0-logloss:0.40325	validation_0-error:0.00000	validation_1-logloss:0.40348	validation_1-error:0.00346
# [386]	validation_0-logloss:0.40275	validation_0-error:0.00000	validation_1-logloss:0.40298	validation_1-error:0.00346
# [387]	validation_0-logloss:0.40225	validation_0-error:0.00000	validation_1-logloss:0.40249	validation_1-error:0.00346
# [388]	validation_0-logloss:0.40175	validation_0-error:0.00000	validation_1-logloss:0.40200	validation_1-error:0.00346
# [389]	validation_0-logloss:0.40125	validation_0-error:0.00000	validation_1-logloss:0.40151	validation_1-error:0.00346
# [390]	validation_0-logloss:0.40076	validation_0-error:0.00000	validation_1-logloss:0.40102	validation_1-error:0.00346
# [391]	validation_0-logloss:0.40026	validation_0-error:0.00000	validation_1-logloss:0.40053	validation_1-error:0.00346
# [392]	validation_0-logloss:0.39976	validation_0-error:0.00000	validation_1-logloss:0.40004	validation_1-error:0.00346
# [393]	validation_0-logloss:0.39927	validation_0-error:0.00000	validation_1-logloss:0.39956	validation_1-error:0.00346
# [394]	validation_0-logloss:0.39878	validation_0-error:0.00000	validation_1-logloss:0.39907	validation_1-error:0.00346
# [395]	validation_0-logloss:0.39828	validation_0-error:0.00000	validation_1-logloss:0.39858	validation_1-error:0.00346
# [396]	validation_0-logloss:0.39779	validation_0-error:0.00000	validation_1-logloss:0.39810	validation_1-error:0.00346
# [397]	validation_0-logloss:0.39730	validation_0-error:0.00000	validation_1-logloss:0.39761	validation_1-error:0.00346
# [398]	validation_0-logloss:0.39681	validation_0-error:0.00000	validation_1-logloss:0.39713	validation_1-error:0.00346
# [399]	validation_0-logloss:0.39632	validation_0-error:0.00000	validation_1-logloss:0.39665	validation_1-error:0.00346
# [400]	validation_0-logloss:0.39583	validation_0-error:0.00000	validation_1-logloss:0.39617	validation_1-error:0.00346
# [401]	validation_0-logloss:0.39534	validation_0-error:0.00000	validation_1-logloss:0.39568	validation_1-error:0.00346
# [402]	validation_0-logloss:0.39485	validation_0-error:0.00000	validation_1-logloss:0.39520	validation_1-error:0.00346
# [403]	validation_0-logloss:0.39436	validation_0-error:0.00000	validation_1-logloss:0.39472	validation_1-error:0.00346
# [404]	validation_0-logloss:0.39388	validation_0-error:0.00000	validation_1-logloss:0.39424	validation_1-error:0.00346
# [405]	validation_0-logloss:0.39339	validation_0-error:0.00000	validation_1-logloss:0.39377	validation_1-error:0.00346
# [406]	validation_0-logloss:0.39290	validation_0-error:0.00000	validation_1-logloss:0.39329	validation_1-error:0.00346
# [407]	validation_0-logloss:0.39242	validation_0-error:0.00000	validation_1-logloss:0.39281	validation_1-error:0.00346
# [408]	validation_0-logloss:0.39194	validation_0-error:0.00000	validation_1-logloss:0.39233	validation_1-error:0.00346
# [409]	validation_0-logloss:0.39145	validation_0-error:0.00000	validation_1-logloss:0.39186	validation_1-error:0.00346
# [410]	validation_0-logloss:0.39097	validation_0-error:0.00000	validation_1-logloss:0.39138	validation_1-error:0.00346
# [411]	validation_0-logloss:0.39049	validation_0-error:0.00000	validation_1-logloss:0.39091	validation_1-error:0.00346
# [412]	validation_0-logloss:0.39001	validation_0-error:0.00000	validation_1-logloss:0.39044	validation_1-error:0.00346
# [413]	validation_0-logloss:0.38953	validation_0-error:0.00000	validation_1-logloss:0.38996	validation_1-error:0.00346
# [414]	validation_0-logloss:0.38905	validation_0-error:0.00000	validation_1-logloss:0.38949	validation_1-error:0.00346
# [415]	validation_0-logloss:0.38857	validation_0-error:0.00000	validation_1-logloss:0.38902	validation_1-error:0.00346
# [416]	validation_0-logloss:0.38809	validation_0-error:0.00000	validation_1-logloss:0.38855	validation_1-error:0.00346
# [417]	validation_0-logloss:0.38762	validation_0-error:0.00000	validation_1-logloss:0.38808	validation_1-error:0.00346
# [418]	validation_0-logloss:0.38714	validation_0-error:0.00000	validation_1-logloss:0.38761	validation_1-error:0.00346
# [419]	validation_0-logloss:0.38667	validation_0-error:0.00000	validation_1-logloss:0.38714	validation_1-error:0.00346
# [420]	validation_0-logloss:0.38619	validation_0-error:0.00000	validation_1-logloss:0.38668	validation_1-error:0.00346
# [421]	validation_0-logloss:0.38572	validation_0-error:0.00000	validation_1-logloss:0.38621	validation_1-error:0.00346
# [422]	validation_0-logloss:0.38524	validation_0-error:0.00000	validation_1-logloss:0.38574	validation_1-error:0.00346
# [423]	validation_0-logloss:0.38477	validation_0-error:0.00000	validation_1-logloss:0.38528	validation_1-error:0.00346
# [424]	validation_0-logloss:0.38430	validation_0-error:0.00000	validation_1-logloss:0.38481	validation_1-error:0.00346
# [425]	validation_0-logloss:0.38383	validation_0-error:0.00000	validation_1-logloss:0.38435	validation_1-error:0.00346
# [426]	validation_0-logloss:0.38336	validation_0-error:0.00000	validation_1-logloss:0.38388	validation_1-error:0.00346
# [427]	validation_0-logloss:0.38289	validation_0-error:0.00000	validation_1-logloss:0.38342	validation_1-error:0.00346
# [428]	validation_0-logloss:0.38242	validation_0-error:0.00000	validation_1-logloss:0.38296	validation_1-error:0.00346
# [429]	validation_0-logloss:0.38195	validation_0-error:0.00000	validation_1-logloss:0.38250	validation_1-error:0.00346
# [430]	validation_0-logloss:0.38148	validation_0-error:0.00000	validation_1-logloss:0.38204	validation_1-error:0.00346
# [431]	validation_0-logloss:0.38101	validation_0-error:0.00000	validation_1-logloss:0.38158	validation_1-error:0.00346
# [432]	validation_0-logloss:0.38055	validation_0-error:0.00000	validation_1-logloss:0.38112	validation_1-error:0.00346
# [433]	validation_0-logloss:0.38008	validation_0-error:0.00000	validation_1-logloss:0.38066	validation_1-error:0.00346
# [434]	validation_0-logloss:0.37962	validation_0-error:0.00000	validation_1-logloss:0.38020	validation_1-error:0.00346
# [435]	validation_0-logloss:0.37915	validation_0-error:0.00000	validation_1-logloss:0.37974	validation_1-error:0.00346
# [436]	validation_0-logloss:0.37869	validation_0-error:0.00000	validation_1-logloss:0.37929	validation_1-error:0.00346
# [437]	validation_0-logloss:0.37822	validation_0-error:0.00000	validation_1-logloss:0.37883	validation_1-error:0.00346
# [438]	validation_0-logloss:0.37776	validation_0-error:0.00000	validation_1-logloss:0.37838	validation_1-error:0.00346
# [439]	validation_0-logloss:0.37730	validation_0-error:0.00000	validation_1-logloss:0.37792	validation_1-error:0.00346
# [440]	validation_0-logloss:0.37684	validation_0-error:0.00000	validation_1-logloss:0.37747	validation_1-error:0.00346
# [441]	validation_0-logloss:0.37638	validation_0-error:0.00000	validation_1-logloss:0.37702	validation_1-error:0.00346
# [442]	validation_0-logloss:0.37592	validation_0-error:0.00000	validation_1-logloss:0.37656	validation_1-error:0.00346
# [443]	validation_0-logloss:0.37546	validation_0-error:0.00000	validation_1-logloss:0.37611	validation_1-error:0.00346
# [444]	validation_0-logloss:0.37500	validation_0-error:0.00000	validation_1-logloss:0.37566	validation_1-error:0.00346
# [445]	validation_0-logloss:0.37455	validation_0-error:0.00000	validation_1-logloss:0.37521	validation_1-error:0.00346
# [446]	validation_0-logloss:0.37409	validation_0-error:0.00000	validation_1-logloss:0.37476	validation_1-error:0.00346
# [447]	validation_0-logloss:0.37363	validation_0-error:0.00000	validation_1-logloss:0.37431	validation_1-error:0.00346
# [448]	validation_0-logloss:0.37318	validation_0-error:0.00000	validation_1-logloss:0.37386	validation_1-error:0.00346
# [449]	validation_0-logloss:0.37272	validation_0-error:0.00000	validation_1-logloss:0.37341	validation_1-error:0.00346
# [450]	validation_0-logloss:0.37227	validation_0-error:0.00000	validation_1-logloss:0.37297	validation_1-error:0.00346
# [451]	validation_0-logloss:0.37182	validation_0-error:0.00000	validation_1-logloss:0.37252	validation_1-error:0.00346
# [452]	validation_0-logloss:0.37136	validation_0-error:0.00000	validation_1-logloss:0.37208	validation_1-error:0.00346
# [453]	validation_0-logloss:0.37091	validation_0-error:0.00000	validation_1-logloss:0.37163	validation_1-error:0.00346
# [454]	validation_0-logloss:0.37046	validation_0-error:0.00000	validation_1-logloss:0.37119	validation_1-error:0.00346
# [455]	validation_0-logloss:0.37001	validation_0-error:0.00000	validation_1-logloss:0.37074	validation_1-error:0.00346
# [456]	validation_0-logloss:0.36956	validation_0-error:0.00000	validation_1-logloss:0.37030	validation_1-error:0.00346
# [457]	validation_0-logloss:0.36911	validation_0-error:0.00000	validation_1-logloss:0.36986	validation_1-error:0.00346
# [458]	validation_0-logloss:0.36866	validation_0-error:0.00000	validation_1-logloss:0.36942	validation_1-error:0.00346
# [459]	validation_0-logloss:0.36821	validation_0-error:0.00000	validation_1-logloss:0.36897	validation_1-error:0.00346
# [460]	validation_0-logloss:0.36777	validation_0-error:0.00000	validation_1-logloss:0.36853	validation_1-error:0.00346
# [461]	validation_0-logloss:0.36732	validation_0-error:0.00000	validation_1-logloss:0.36809	validation_1-error:0.00346
# [462]	validation_0-logloss:0.36687	validation_0-error:0.00000	validation_1-logloss:0.36766	validation_1-error:0.00346
# [463]	validation_0-logloss:0.36643	validation_0-error:0.00000	validation_1-logloss:0.36722	validation_1-error:0.00346
# [464]	validation_0-logloss:0.36598	validation_0-error:0.00000	validation_1-logloss:0.36678	validation_1-error:0.00346
# [465]	validation_0-logloss:0.36554	validation_0-error:0.00000	validation_1-logloss:0.36634	validation_1-error:0.00346
# [466]	validation_0-logloss:0.36509	validation_0-error:0.00000	validation_1-logloss:0.36591	validation_1-error:0.00346
# [467]	validation_0-logloss:0.36465	validation_0-error:0.00000	validation_1-logloss:0.36547	validation_1-error:0.00346
# [468]	validation_0-logloss:0.36421	validation_0-error:0.00000	validation_1-logloss:0.36503	validation_1-error:0.00346
# [469]	validation_0-logloss:0.36377	validation_0-error:0.00000	validation_1-logloss:0.36460	validation_1-error:0.00346
# [470]	validation_0-logloss:0.36333	validation_0-error:0.00000	validation_1-logloss:0.36417	validation_1-error:0.00346
# [471]	validation_0-logloss:0.36289	validation_0-error:0.00000	validation_1-logloss:0.36373	validation_1-error:0.00346
# [472]	validation_0-logloss:0.36245	validation_0-error:0.00000	validation_1-logloss:0.36330	validation_1-error:0.00346
# [473]	validation_0-logloss:0.36201	validation_0-error:0.00000	validation_1-logloss:0.36287	validation_1-error:0.00346
# [474]	validation_0-logloss:0.36157	validation_0-error:0.00000	validation_1-logloss:0.36244	validation_1-error:0.00346
# [475]	validation_0-logloss:0.36113	validation_0-error:0.00000	validation_1-logloss:0.36201	validation_1-error:0.00346
# [476]	validation_0-logloss:0.36070	validation_0-error:0.00000	validation_1-logloss:0.36158	validation_1-error:0.00346
# [477]	validation_0-logloss:0.36026	validation_0-error:0.00000	validation_1-logloss:0.36115	validation_1-error:0.00346
# [478]	validation_0-logloss:0.35982	validation_0-error:0.00000	validation_1-logloss:0.36072	validation_1-error:0.00346
# [479]	validation_0-logloss:0.35939	validation_0-error:0.00000	validation_1-logloss:0.36029	validation_1-error:0.00346
# [480]	validation_0-logloss:0.35895	validation_0-error:0.00000	validation_1-logloss:0.35986	validation_1-error:0.00346
# [481]	validation_0-logloss:0.35852	validation_0-error:0.00000	validation_1-logloss:0.35943	validation_1-error:0.00346
# [482]	validation_0-logloss:0.35809	validation_0-error:0.00000	validation_1-logloss:0.35901	validation_1-error:0.00346
# [483]	validation_0-logloss:0.35766	validation_0-error:0.00000	validation_1-logloss:0.35858	validation_1-error:0.00346
# [484]	validation_0-logloss:0.35722	validation_0-error:0.00000	validation_1-logloss:0.35816	validation_1-error:0.00346
# [485]	validation_0-logloss:0.35679	validation_0-error:0.00000	validation_1-logloss:0.35773	validation_1-error:0.00346
# [486]	validation_0-logloss:0.35636	validation_0-error:0.00000	validation_1-logloss:0.35731	validation_1-error:0.00346
# [487]	validation_0-logloss:0.35593	validation_0-error:0.00000	validation_1-logloss:0.35689	validation_1-error:0.00346
# [488]	validation_0-logloss:0.35550	validation_0-error:0.00000	validation_1-logloss:0.35646	validation_1-error:0.00346
# [489]	validation_0-logloss:0.35507	validation_0-error:0.00000	validation_1-logloss:0.35604	validation_1-error:0.00346
# [490]	validation_0-logloss:0.35465	validation_0-error:0.00000	validation_1-logloss:0.35562	validation_1-error:0.00346
# [491]	validation_0-logloss:0.35422	validation_0-error:0.00000	validation_1-logloss:0.35520	validation_1-error:0.00346
# [492]	validation_0-logloss:0.35379	validation_0-error:0.00000	validation_1-logloss:0.35478	validation_1-error:0.00346
# [493]	validation_0-logloss:0.35336	validation_0-error:0.00000	validation_1-logloss:0.35436	validation_1-error:0.00346
# [494]	validation_0-logloss:0.35294	validation_0-error:0.00000	validation_1-logloss:0.35394	validation_1-error:0.00346
# [495]	validation_0-logloss:0.35251	validation_0-error:0.00000	validation_1-logloss:0.35352	validation_1-error:0.00346
# [496]	validation_0-logloss:0.35209	validation_0-error:0.00000	validation_1-logloss:0.35311	validation_1-error:0.00346
# [497]	validation_0-logloss:0.35167	validation_0-error:0.00000	validation_1-logloss:0.35269	validation_1-error:0.00346
# [498]	validation_0-logloss:0.35124	validation_0-error:0.00000	validation_1-logloss:0.35227	validation_1-error:0.00346
# [499]	validation_0-logloss:0.35082	validation_0-error:0.00000	validation_1-logloss:0.35186	validation_1-error:0.00346
# Test Accuracy: 99.94797%
# Test F1 Score: 0.99946
# Test Precision: 0.99936
# Test Recall: 0.99956
# Test ROC AUC: 0.99956

# %%
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.linear_model import LogisticRegression
# from sklearn.svm import SVC
# from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
# import xgboost as xgb
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler


# scaler = StandardScaler()
# X_train_features = scaler.fit_transform(X_train_features)
# X_val_features = scaler.transform(X_val_features)
# X_test_features = scaler.transform(X_test_features)


# lr = LogisticRegression(max_iter=500)
# rf = RandomForestClassifier(n_estimators=100)
# svm = SVC(probability=True)


# lr.fit(X_train_features, y_train_single)
# rf.fit(X_train_features, y_train_single)
# svm.fit(X_train_features, y_train_single)


# lr_train_pred = lr.predict_proba(X_train_features)
# rf_train_pred = rf.predict_proba(X_train_features)
# svm_train_pred = svm.predict_proba(X_train_features)


# meta_X_train = np.hstack((lr_train_pred, rf_train_pred, svm_train_pred))


# lr_val_pred = lr.predict_proba(X_val_features)
# rf_val_pred = rf.predict_proba(X_val_features)
# svm_val_pred = svm.predict_proba(X_val_features)
# meta_X_val = np.hstack((lr_val_pred, rf_val_pred, svm_val_pred))


# meta_learner = xgb.XGBClassifier(n_estimators=200, learning_rate=0.01, max_depth=4, eval_metric=['logloss', 'error'], use_label_encoder=False)


# eval_set = [(meta_X_train, y_train_single), (meta_X_val, y_val_single)]


# meta_learner.fit(meta_X_train, y_train_single, eval_set=eval_set, verbose=True)


# lr_test_pred = lr.predict_proba(X_test_features)
# rf_test_pred = rf.predict_proba(X_test_features)
# svm_test_pred = svm.predict_proba(X_test_features)
# meta_X_test = np.hstack((lr_test_pred, rf_test_pred, svm_test_pred))

# y_pred = meta_learner.predict(meta_X_test)


# accuracy = accuracy_score(y_test_single, y_pred)
# f1 = f1_score(y_test_single, y_pred, average='macro')
# precision = precision_score(y_test_single, y_pred, average='macro')
# recall = recall_score(y_test_single, y_pred, average='macro')
# roc_auc = roc_auc_score(y_test_single, y_pred)

# print(f'Accuracy: {accuracy}')
# print(f'F1 Score: {f1}')
# print(f'Precision: {precision}')
# print(f'Recall: {recall}')
# print(f'ROC AUC: {roc_auc}')
